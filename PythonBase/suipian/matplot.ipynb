# %%
import matplotlib.pyplot as plt
from numpy.random import randn
from pandas import *
import numpy as np

# %%
fig,axes = plt.subplots(2,2,sharex=True,sharey=True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(randn(500),bins=50,color="k",alpha=0.5)
plt.subplots_adjust(wspace=1,hspace=1)#设置四幅图片的间距

# %%
plt.plot(randn(30).cumsum(),'ko--')
# cumsum返回：沿着指定轴的元素累加和所组成的数组，其形状应与输入数组a一致

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(randn(1000).cumsum())
ticks = ax.set_xticks([0,25,500,750,1000])
labels = ax.set_xticklabels(['one','two','three','four','five'])
ax.set_title("my first matplotlib plot")
ax.set_xlabel("stages")
# Out:
# Text(0.5, 0, 'stages')

# %%
df = DataFrame(np.random.randn(10,4).cumsum(0),
                columns=['A','B','C','D'],
                index=np.arange(0,100,10))
                # DF的plot方法在subplot中为各列绘制一条线
                # 参数见P247
df.plot()
# Out:
# C:\Users\dly\AppData\Local\Temp/ipykernel_7676/324788807.py:8: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "dip" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('shabi.png',dip=400,bbox_inches='tight')#(名称，分辨率，剪空白部分)

# %%
#添加图例
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(randn(1000).cumsum(),'k',label='one')
ax.plot(randn(1000).cumsum(),'k--',label='two')
ax.plot(randn(1000).cumsum(),'k.',label='three')
ax.legend(loc='best')#对图片添加注释
plt.savefig('shabi.png',dip=400,bbox_inches='tight')#(名称，分辨率，剪空白部分)

# %%
#在图表中添加图形
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
rect = plt.Rectangle((0.2,0.75),0.4,0.15,color='g',alpha=0.3)#(坐标，长，宽，颜色，xx)
ax.add_patch(rect)

# %%
# pandas绘图
s = Series(np.random.randn(10).cumsum(),index=np.arange(1,100,10))
# 参数见P246
s.plot()
# Out:
# <AxesSubplot:>

# %%
# 柱状图
fig,axes = plt.subplots(2,1)
a=[1,2,3,4,5]
data = Series(randn(16),index=list('abcdefghigklmnop'))
data.plot(kind='bar',ax=axes[0],color='k',alpha=0.7)
# bar垂直柱状图
data.plot(kind='barh',ax=axes[1],color='g',alpha=0.7)
# barh水平柱状图

#fig , ax = plt.subplots(nrows, ncols)
#函数的返回值是一个元组，包括一个图形对象和所有的 axes 对象。其中 axes 对象的数量等于 nrows * ncols，且每个 axes 对象均可通过索引值访问（从1开始
# Out:
# <AxesSubplot:>

# %%
# 创建散布图
macro = read_csv('E:\\微软下载\\PythonForDataAnalysis-master\\ch08\\macrodata.csv')
data = macro[['cpi','m1','tbilrate','unemp']]
trans_data = np.log(data).diff().dropna()
trans_data[-5:]
plt.scatter(trans_data['m1'],trans_data['unemp'])
plt.title('Change in log %s vs. log %s' % ('m1','unemp'))

# 散布图矩阵
pandas.plotting.scatter_matrix(trans_data,color='g',alpha=0.5)
# 新版的要加上.plotting
# Out:
# array([[<AxesSubplot:xlabel='cpi', ylabel='cpi'>,
#         <AxesSubplot:xlabel='m1', ylabel='cpi'>,
#         <AxesSubplot:xlabel='tbilrate', ylabel='cpi'>,
#         <AxesSubplot:xlabel='unemp', ylabel='cpi'>],
#        [<AxesSubplot:xlabel='cpi', ylabel='m1'>,
#         <AxesSubplot:xlabel='m1', ylabel='m1'>,
#         <AxesSubplot:xlabel='tbilrate', ylabel='m1'>,
#         <AxesSubplot:xlabel='unemp', ylabel='m1'>],
#        [<AxesSubplot:xlabel='cpi', ylabel='tbilrate'>,
#         <AxesSubplot:xlabel='m1', ylabel='tbilrate'>,
#         <AxesSubplot:xlabel='tbilrate', ylabel='tbilrate'>,
#         <AxesSubplot:xlabel='unemp', ylabel='tbilrate'>],
#        [<AxesSubplot:xlabel='cpi', ylabel='unemp'>,
#         <AxesSubplot:xlabel='m1', ylabel='unemp'>,
#         <AxesSubplot:xlabel='tbilrate', ylabel='unemp'>,
#         <AxesSubplot:xlabel='unemp', ylabel='unemp'>]], dtype=object)

# %%
#第三节：画出地震等级
