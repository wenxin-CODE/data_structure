# %%
# -*- coding: utf-8 -*-
import random
import copy
import time
import sys
import math
import tkinter #//GUI模块
import threading
from functools import reduce


# 参数
'''
ALPHA:信息启发因子，值越大，则蚂蚁选择之前走过的路径可能性就越大
      ，值越小，则蚁群搜索范围就会减少，容易陷入局部最优
BETA:Beta值越大，蚁群越就容易选择局部较短路径，这时算法收敛速度会
     加快，但是随机性不高，容易得到局部的相对最优
'''
(ALPHA, BETA, RHO, Q) = (1.0,2.0,0.5,100.0)
# 城市数，蚁群
(city_num, ant_num) = (50,50)
distance_x = [
    178,272,176,171,650,499,267,703,408,437,491,74,532,
    416,626,42,271,359,163,508,229,576,147,560,35,714,
    757,517,64,314,675,690,391,628,87,240,705,699,258,
    428,614,36,360,482,666,597,209,201,492,294]
distance_y = [
    170,395,198,151,242,556,57,401,305,421,267,105,525,
    381,244,330,395,169,141,380,153,442,528,329,232,48,
    498,265,343,120,165,50,433,63,491,275,348,222,288,
    490,213,524,244,114,104,552,70,425,227,331]
#城市距离和信息素
distance_graph = [ [0.0 for col in range(city_num)] for raw in range(city_num)]
pheromone_graph = [ [1.0 for col in range(city_num)] for raw in range(city_num)]



#----------- 蚂蚁 -----------
class Ant(object):

    # 初始化
    def __init__(self,ID):

        self.ID = ID                 # ID
        self.__clean_data()          # 随机初始化出生点

    # 初始数据
    def __clean_data(self):

        self.path = []               # 当前蚂蚁的路径           
        self.total_distance = 0.0    # 当前路径的总距离
        self.move_count = 0          # 移动次数
        self.current_city = -1       # 当前停留的城市
        self.open_table_city = [True for i in range(city_num)] # 探索城市的状态

        city_index = random.randint(0,city_num-1) # 随机初始出生点
        self.current_city = city_index
        self.path.append(city_index)
        self.open_table_city[city_index] = False
        self.move_count = 1

    # 选择下一个城市
    def __choice_next_city(self):

        next_city = -1
        select_citys_prob = [0.0 for i in range(city_num)]  #存储去下个城市的概率
        total_prob = 0.0

        # 获取去下一个城市的概率
        for i in range(city_num):
            if self.open_table_city[i]:
                try :
                    # 计算概率：与信息素浓度成正比，与距离成反比
                    select_citys_prob[i] = pow(pheromone_graph[self.current_city][i], ALPHA) * pow((1.0/distance_graph[self.current_city][i]), BETA)
                    total_prob += select_citys_prob[i]
                except ZeroDivisionError as e:
                    print ('Ant ID: {ID}, current city: {current}, target city: {target}'.format(ID = self.ID, current = self.current_city, target = i))
                    sys.exit(1)

        # 轮盘选择城市
        if total_prob > 0.0:
            # 产生一个随机概率,0.0-total_prob
            temp_prob = random.uniform(0.0, total_prob)
            for i in range(city_num):
                if self.open_table_city[i]:
                    # 轮次相减
                    temp_prob -= select_citys_prob[i]
                    if temp_prob < 0.0:
                        next_city = i
                        break

        # 未从概率产生，顺序选择一个未访问城市
        # if next_city == -1:
        #     for i in range(city_num):
        #         if self.open_table_city[i]:
        #             next_city = i
        #             break

        if (next_city == -1):
            next_city = random.randint(0, city_num - 1)
            while ((self.open_table_city[next_city]) == False):  # if==False,说明已经遍历过了
                next_city = random.randint(0, city_num - 1)

        # 返回下一个城市序号
        return next_city

    # 计算路径总距离
    def __cal_total_distance(self):

        temp_distance = 0.0

        for i in range(1, city_num):
            start, end = self.path[i], self.path[i-1]
            temp_distance += distance_graph[start][end]

        # 回路
        end = self.path[0]
        temp_distance += distance_graph[start][end]
        self.total_distance = temp_distance


    # 移动操作
    def __move(self, next_city):

        self.path.append(next_city)
        self.open_table_city[next_city] = False
        self.total_distance += distance_graph[self.current_city][next_city]
        self.current_city = next_city
        self.move_count += 1

    # 搜索路径
    def search_path(self):

        # 初始化数据
        self.__clean_data()

        # 搜素路径，遍历完所有城市为止
        while self.move_count < city_num:
            # 移动到下一个城市
            next_city =  self.__choice_next_city()
            self.__move(next_city)

        # 计算路径总长度
        self.__cal_total_distance()

#----------- TSP问题 -----------

class TSP(object):

    def __init__(self, root, width = 800, height = 600, n = city_num):

        # 创建画布
        self.root = root                               
        self.width = width      
        self.height = height
        # 城市数目初始化为city_num
        self.n = n
        # tkinter.Canvas
        self.canvas = tkinter.Canvas(
                root,
                width = self.width,
                height = self.height,
                bg = "#EBEBEB",             # 背景白色 
                xscrollincrement = 1,
                yscrollincrement = 1
            )
        self.canvas.pack(expand = tkinter.YES, fill = tkinter.BOTH)
        self.title("TSP蚁群算法(n:初始化 e:开始搜索 s:停止搜索 q:退出程序)")
        self.__r = 5
        self.__lock = threading.RLock()     # 线程锁

        self.__bindEvents()
        self.new()

        # 计算城市之间的距离
        for i in range(city_num):
            for j in range(city_num):
                temp_distance = pow((distance_x[i] - distance_x[j]), 2) + pow((distance_y[i] - distance_y[j]), 2)
                temp_distance = pow(temp_distance, 0.5)
                distance_graph[i][j] =float(int(temp_distance + 0.5))

    # 按键响应程序
    def __bindEvents(self):

        self.root.bind("q", self.quite)        # 退出程序
        self.root.bind("n", self.new)          # 初始化
        self.root.bind("e", self.search_path)  # 开始搜索
        self.root.bind("s", self.stop)         # 停止搜索

    # 更改标题
    def title(self, s):

        self.root.title(s)

    # 初始化
    def new(self, evt = None):

        # 停止线程
        self.__lock.acquire()
        self.__running = False
        self.__lock.release()

        self.clear()     # 清除信息 
        self.nodes = []  # 节点坐标
        self.nodes2 = [] # 节点对象

        # 初始化城市节点
        for i in range(len(distance_x)):
            # 在画布上随机初始坐标
            x = distance_x[i]
            y = distance_y[i]
            self.nodes.append((x, y))
            # 生成节点椭圆，半径为self.__r
            node = self.canvas.create_oval(x - self.__r,
                    y - self.__r, x + self.__r, y + self.__r,
                    fill = "#ff0000",      # 填充红色
                    outline = "#000000",   # 轮廓白色
                    tags = "node",
                )
            self.nodes2.append(node)
            # 显示坐标
            self.canvas.create_text(x,y-10,              # 使用create_text方法在坐标（302，77）处绘制文字
                    text = '('+str(x)+','+str(y)+')',    # 所绘制文字的内容
                    fill = 'black'                       # 所绘制文字的颜色为灰色
                )

        # 顺序连接城市
        #self.line(range(city_num))

        # 初始城市之间的距离和信息素
        for i in range(city_num):
            for j in range(city_num):
                pheromone_graph[i][j] = 1.0

        self.ants = [Ant(ID) for ID in range(ant_num)]  # 初始蚁群
        self.best_ant = Ant(-1)                          # 初始最优解
        self.best_ant.total_distance = 1 << 31           # 初始最大距离
        self.iter = 1                                    # 初始化迭代次数 

    # 将节点按order顺序连线
    def line(self, order):
        # 删除原线
        self.canvas.delete("line")
        def line2(i1, i2):
            p1, p2 = self.nodes[i1], self.nodes[i2]
            self.canvas.create_line(p1, p2, fill = "#000000", tags = "line")
            return i2

        # order[-1]为初始值
        reduce(line2, order, order[-1])

    # 清除画布
    def clear(self):
        for item in self.canvas.find_all():
            self.canvas.delete(item)

    # 退出程序
    def quite(self, evt):
        self.__lock.acquire()
        self.__running = False
        self.__lock.release()
        self.root.destroy()
        print (u"\n程序已退出...")
        sys.exit()

    # 停止搜索
    def stop(self, evt):
        self.__lock.acquire()
        self.__running = False
        self.__lock.release()

    # 开始搜索
    def search_path(self, evt = None):

        # 开启线程
        self.__lock.acquire()
        self.__running = True
        self.__lock.release()

        while self.__running:
            # 遍历每一只蚂蚁
            for ant in self.ants:
                # 搜索一条路径
                ant.search_path()
                # 与当前最优蚂蚁比较
                if ant.total_distance < self.best_ant.total_distance:
                    # 更新最优解
                    self.best_ant = copy.deepcopy(ant)
            # 更新信息素
            self.__update_pheromone_gragh()
            print (u"迭代次数：",self.iter,u"最佳路径总距离：",int(self.best_ant.total_distance))
            # 连线
            self.line(self.best_ant.path)
            # 设置标题
            self.title("TSP蚁群算法(n:随机初始 e:开始搜索 s:停止搜索 q:退出程序) 迭代次数: %d" % self.iter)
            # 更新画布
            self.canvas.update()
            self.iter += 1

    # 更新信息素
    def __update_pheromone_gragh(self):

        # 获取每只蚂蚁在其路径上留下的信息素
        temp_pheromone = [[0.0 for col in range(city_num)] for raw in range(city_num)]
        for ant in self.ants:
            for i in range(1,city_num):
                start, end = ant.path[i-1], ant.path[i]
                # 在路径上的每两个相邻城市间留下信息素，与路径总距离反比
                temp_pheromone[start][end] += Q / ant.total_distance
                temp_pheromone[end][start] = temp_pheromone[start][end]

        # 更新所有城市之间的信息素，旧信息素衰减加上新迭代信息素
        for i in range(city_num):
            for j in range(city_num):
                pheromone_graph[i][j] = pheromone_graph[i][j] * RHO + temp_pheromone[i][j]

    # 主循环
    def mainloop(self):
        self.root.mainloop()

#----------- 程序的入口处 -----------

if __name__ == '__main__':


    TSP(tkinter.Tk()).mainloop()
# Out:
# 迭代次数： 1 最佳路径总距离： 7180
# 迭代次数： 2 最佳路径总距离： 6704
# 迭代次数： 3 最佳路径总距离： 6073
# 迭代次数： 4 最佳路径总距离： 5197
# 迭代次数： 5 最佳路径总距离： 5197
# 迭代次数： 6 最佳路径总距离： 4837
# 迭代次数： 7 最佳路径总距离： 4821
# 迭代次数： 8 最佳路径总距离： 4636
# 迭代次数： 9 最佳路径总距离： 4313
# 迭代次数： 10 最佳路径总距离： 3940
# 迭代次数： 11 最佳路径总距离： 3940
# 迭代次数： 12 最佳路径总距离： 3940
# 迭代次数： 13 最佳路径总距离： 3890
# 迭代次数： 14 最佳路径总距离： 3883
# 迭代次数： 15 最佳路径总距离： 3883
# 迭代次数： 16 最佳路径总距离： 3883
# 迭代次数： 17 最佳路径总距离： 3883
# 迭代次数： 18 最佳路径总距离： 3883
# 迭代次数： 19 最佳路径总距离： 3883
# 迭代次数： 20 最佳路径总距离： 3883
# 迭代次数： 21 最佳路径总距离： 3883
# 迭代次数： 22 最佳路径总距离： 3883
# 迭代次数： 23 最佳路径总距离： 3883
# 迭代次数： 24 最佳路径总距离： 3883
# 迭代次数： 25 最佳路径总距离： 3883
# 迭代次数： 26 最佳路径总距离： 3883
# 迭代次数： 27 最佳路径总距离： 3883
# 迭代次数： 28 最佳路径总距离： 3883
# 迭代次数： 29 最佳路径总距离： 3873
# 迭代次数： 30 最佳路径总距离： 3873
# 迭代次数： 31 最佳路径总距离： 3873
# 迭代次数： 32 最佳路径总距离： 3873
# 迭代次数： 33 最佳路径总距离： 3873
# 迭代次数： 34 最佳路径总距离： 3873
# 迭代次数： 35 最佳路径总距离： 3826
# 迭代次数： 36 最佳路径总距离： 3826
# 迭代次数： 37 最佳路径总距离： 3807
# 迭代次数： 38 最佳路径总距离： 3807
# 迭代次数： 39 最佳路径总距离： 3807
# 迭代次数： 40 最佳路径总距离： 3807
# 迭代次数： 41 最佳路径总距离： 3807
# 迭代次数： 42 最佳路径总距离： 3807
# 迭代次数： 43 最佳路径总距离： 3807
# 迭代次数： 44 最佳路径总距离： 3807
# 迭代次数： 45 最佳路径总距离： 3807
# 迭代次数： 46 最佳路径总距离： 3807
# 迭代次数： 47 最佳路径总距离： 3807
# 迭代次数： 48 最佳路径总距离： 3807
# 迭代次数： 49 最佳路径总距离： 3807
# 迭代次数： 50 最佳路径总距离： 3807
# 迭代次数： 51 最佳路径总距离： 3807
# 迭代次数： 52 最佳路径总距离： 3807
# 迭代次数： 53 最佳路径总距离： 3807
# 迭代次数： 54 最佳路径总距离： 3807
# 迭代次数： 55 最佳路径总距离： 3807
# 迭代次数： 56 最佳路径总距离： 3807
# 迭代次数： 57 最佳路径总距离： 3807
# 迭代次数： 58 最佳路径总距离： 3807
# 迭代次数： 59 最佳路径总距离： 3807
# 迭代次数： 60 最佳路径总距离： 3807
# 迭代次数： 61 最佳路径总距离： 3807
# 迭代次数： 62 最佳路径总距离： 3807
# 迭代次数： 63 最佳路径总距离： 3807
# 迭代次数： 64 最佳路径总距离： 3807
# 迭代次数： 65 最佳路径总距离： 3807
# 迭代次数： 66 最佳路径总距离： 3807
# 迭代次数： 67 最佳路径总距离： 3807
# 迭代次数： 68 最佳路径总距离： 3807
# 迭代次数： 69 最佳路径总距离： 3805
# 迭代次数： 70 最佳路径总距离： 3805
# 迭代次数： 71 最佳路径总距离： 3805
# 迭代次数： 72 最佳路径总距离： 3805
# 迭代次数： 73 最佳路径总距离： 3805
# 迭代次数： 74 最佳路径总距离： 3805
# 迭代次数： 75 最佳路径总距离： 3805
# 迭代次数： 76 最佳路径总距离： 3805
# 迭代次数： 77 最佳路径总距离： 3805
# 迭代次数： 78 最佳路径总距离： 3805
# 迭代次数： 79 最佳路径总距离： 3805
# 迭代次数： 80 最佳路径总距离： 3805
# 迭代次数： 81 最佳路径总距离： 3805
# 迭代次数： 82 最佳路径总距离： 3805
# 迭代次数： 83 最佳路径总距离： 3805
# 迭代次数： 84 最佳路径总距离： 3805
# 迭代次数： 85 最佳路径总距离： 3805
# 迭代次数： 86 最佳路径总距离： 3805
# 迭代次数： 87 最佳路径总距离： 3805
# 迭代次数： 88 最佳路径总距离： 3805
# 迭代次数： 89 最佳路径总距离： 3805
# 迭代次数： 90 最佳路径总距离： 3805
# 迭代次数： 91 最佳路径总距离： 3805
# 迭代次数： 92 最佳路径总距离： 3805
# 迭代次数： 93 最佳路径总距离： 3805
# 迭代次数： 94 最佳路径总距离： 3805
# 迭代次数： 95 最佳路径总距离： 3805
# 迭代次数： 96 最佳路径总距离： 3805
# 迭代次数： 97 最佳路径总距离： 3805
# 迭代次数： 98 最佳路径总距离： 3805
# 迭代次数： 99 最佳路径总距离： 3805
# 迭代次数： 100 最佳路径总距离： 3805
# 迭代次数： 101 最佳路径总距离： 3805
# 迭代次数： 102 最佳路径总距离： 3805
# 迭代次数： 103 最佳路径总距离： 3805
# 迭代次数： 104 最佳路径总距离： 3805
# 迭代次数： 105 最佳路径总距离： 3805
# 迭代次数： 106 最佳路径总距离： 3805
# 迭代次数： 107 最佳路径总距离： 3805
# 迭代次数： 108 最佳路径总距离： 3805
# 迭代次数： 109 最佳路径总距离： 3805
# 迭代次数： 110 最佳路径总距离： 3805
# 迭代次数： 111 最佳路径总距离： 3805
# 迭代次数： 112 最佳路径总距离： 3805
# 迭代次数： 113 最佳路径总距离： 3805
# 迭代次数： 114 最佳路径总距离： 3805
# 迭代次数： 115 最佳路径总距离： 3805
# 迭代次数： 116 最佳路径总距离： 3795
# 迭代次数： 117 最佳路径总距离： 3795
# 迭代次数： 118 最佳路径总距离： 3795
# 迭代次数： 119 最佳路径总距离： 3795
# 迭代次数： 120 最佳路径总距离： 3795
# 迭代次数： 121 最佳路径总距离： 3795
# 迭代次数： 122 最佳路径总距离： 3795
# 迭代次数： 123 最佳路径总距离： 3795
# 迭代次数： 124 最佳路径总距离： 3795
# 迭代次数： 125 最佳路径总距离： 3795
# 迭代次数： 126 最佳路径总距离： 3795
# 迭代次数： 127 最佳路径总距离： 3795
# 迭代次数： 128 最佳路径总距离： 3795
# 迭代次数： 129 最佳路径总距离： 3795
# 迭代次数： 130 最佳路径总距离： 3795
# 迭代次数： 131 最佳路径总距离： 3795
# 迭代次数： 132 最佳路径总距离： 3795
# 迭代次数： 133 最佳路径总距离： 3795
# 迭代次数： 134 最佳路径总距离： 3795
# 迭代次数： 135 最佳路径总距离： 3795
# 迭代次数： 136 最佳路径总距离： 3795
# 迭代次数： 137 最佳路径总距离： 3795
# 迭代次数： 138 最佳路径总距离： 3795
# 迭代次数： 139 最佳路径总距离： 3795
# 迭代次数： 140 最佳路径总距离： 3756
# 迭代次数： 141 最佳路径总距离： 3756
# 迭代次数： 142 最佳路径总距离： 3756
# 迭代次数： 143 最佳路径总距离： 3756
# 迭代次数： 144 最佳路径总距离： 3756
# 迭代次数： 145 最佳路径总距离： 3756
# 迭代次数： 146 最佳路径总距离： 3756
# 迭代次数： 147 最佳路径总距离： 3756
# 迭代次数： 148 最佳路径总距离： 3756
# 迭代次数： 149 最佳路径总距离： 3756
# 迭代次数： 150 最佳路径总距离： 3756
# 迭代次数： 151 最佳路径总距离： 3756
# 迭代次数： 152 最佳路径总距离： 3756
# 迭代次数： 153 最佳路径总距离： 3756
# 迭代次数： 154 最佳路径总距离： 3756
# 迭代次数： 155 最佳路径总距离： 3756
# 迭代次数： 156 最佳路径总距离： 3756
# 迭代次数： 157 最佳路径总距离： 3756
# 迭代次数： 158 最佳路径总距离： 3756
# 迭代次数： 159 最佳路径总距离： 3756
# 迭代次数： 160 最佳路径总距离： 3756
# 迭代次数： 161 最佳路径总距离： 3756
# 迭代次数： 162 最佳路径总距离： 3756
# 迭代次数： 163 最佳路径总距离： 3756
# 迭代次数： 164 最佳路径总距离： 3756
# 迭代次数： 165 最佳路径总距离： 3756
# 迭代次数： 166 最佳路径总距离： 3756
# 迭代次数： 167 最佳路径总距离： 3756
# 迭代次数： 168 最佳路径总距离： 3756
# 迭代次数： 169 最佳路径总距离： 3756
# 迭代次数： 170 最佳路径总距离： 3756
# 迭代次数： 171 最佳路径总距离： 3756
# 迭代次数： 172 最佳路径总距离： 3756
# 迭代次数： 173 最佳路径总距离： 3756
# 迭代次数： 174 最佳路径总距离： 3756
# 迭代次数： 175 最佳路径总距离： 3756
# 迭代次数： 176 最佳路径总距离： 3756
# 迭代次数： 177 最佳路径总距离： 3756
# 迭代次数： 178 最佳路径总距离： 3756
# 迭代次数： 179 最佳路径总距离： 3756
# 迭代次数： 180 最佳路径总距离： 3756
# 迭代次数： 181 最佳路径总距离： 3756
# 迭代次数： 182 最佳路径总距离： 3756
# 迭代次数： 183 最佳路径总距离： 3756
# 迭代次数： 184 最佳路径总距离： 3756
# 迭代次数： 185 最佳路径总距离： 3756
# 迭代次数： 186 最佳路径总距离： 3756
# 迭代次数： 187 最佳路径总距离： 3756
# 迭代次数： 188 最佳路径总距离： 3756
# 迭代次数： 189 最佳路径总距离： 3756
# 迭代次数： 190 最佳路径总距离： 3756
# 迭代次数： 191 最佳路径总距离： 3756
# 迭代次数： 192 最佳路径总距离： 3756
# 迭代次数： 193 最佳路径总距离： 3756
# 迭代次数： 194 最佳路径总距离： 3756
# 迭代次数： 195 最佳路径总距离： 3756
# 迭代次数： 196 最佳路径总距离： 3756
# 迭代次数： 197 最佳路径总距离： 3756
# 迭代次数： 198 最佳路径总距离： 3756
# 迭代次数： 199 最佳路径总距离： 3756
# 迭代次数： 200 最佳路径总距离： 3756
# 迭代次数： 201 最佳路径总距离： 3756
# 迭代次数： 202 最佳路径总距离： 3756
# 迭代次数： 203 最佳路径总距离： 3756
# 迭代次数： 204 最佳路径总距离： 3756
# 迭代次数： 205 最佳路径总距离： 3756
# 迭代次数： 206 最佳路径总距离： 3756
# 迭代次数： 207 最佳路径总距离： 3756
# 迭代次数： 208 最佳路径总距离： 3756
# 迭代次数： 209 最佳路径总距离： 3756
# 迭代次数： 210 最佳路径总距离： 3756
# 迭代次数： 211 最佳路径总距离： 3756
# 迭代次数： 212 最佳路径总距离： 3756
# 迭代次数： 213 最佳路径总距离： 3756
# 迭代次数： 214 最佳路径总距离： 3756
# 迭代次数： 215 最佳路径总距离： 3756
# 迭代次数： 216 最佳路径总距离： 3756
# 迭代次数： 217 最佳路径总距离： 3756
# 迭代次数： 218 最佳路径总距离： 3756
# 迭代次数： 219 最佳路径总距离： 3756
# 迭代次数： 220 最佳路径总距离： 3756
# 迭代次数： 221 最佳路径总距离： 3756
# 迭代次数： 222 最佳路径总距离： 3756
# 迭代次数： 223 最佳路径总距离： 3756
# 迭代次数： 224 最佳路径总距离： 3756
# 迭代次数： 225 最佳路径总距离： 3756
# 迭代次数： 226 最佳路径总距离： 3756
# 迭代次数： 227 最佳路径总距离： 3756
# 迭代次数： 228 最佳路径总距离： 3756
# 迭代次数： 229 最佳路径总距离： 3756
# 迭代次数： 230 最佳路径总距离： 3756
# 迭代次数： 231 最佳路径总距离： 3756
# 迭代次数： 232 最佳路径总距离： 3756
# 迭代次数： 233 最佳路径总距离： 3756
# 迭代次数： 234 最佳路径总距离： 3756
# 迭代次数： 235 最佳路径总距离： 3756
# 迭代次数： 236 最佳路径总距离： 3756
# 迭代次数： 237 最佳路径总距离： 3756
# 迭代次数： 238 最佳路径总距离： 3756
# 迭代次数： 239 最佳路径总距离： 3756
# 迭代次数： 240 最佳路径总距离： 3756
# 迭代次数： 241 最佳路径总距离： 3756
# 迭代次数： 242 最佳路径总距离： 3756
# 迭代次数： 243 最佳路径总距离： 3756
# 迭代次数： 244 最佳路径总距离： 3756
# 迭代次数： 245 最佳路径总距离： 3756
# 迭代次数： 246 最佳路径总距离： 3756
# 迭代次数： 247 最佳路径总距离： 3756
# 迭代次数： 248 最佳路径总距离： 3756
# 迭代次数： 249 最佳路径总距离： 3756
# 迭代次数： 250 最佳路径总距离： 3756
# 迭代次数： 251 最佳路径总距离： 3756
# 迭代次数： 252 最佳路径总距离： 3756
# 迭代次数： 253 最佳路径总距离： 3756
# 迭代次数： 254 最佳路径总距离： 3756
# 迭代次数： 255 最佳路径总距离： 3756
# 迭代次数： 256 最佳路径总距离： 3756
# 迭代次数： 257 最佳路径总距离： 3756
# 迭代次数： 258 最佳路径总距离： 3756
# 迭代次数： 259 最佳路径总距离： 3756
# 迭代次数： 260 最佳路径总距离： 3756
# 迭代次数： 261 最佳路径总距离： 3756
# 迭代次数： 262 最佳路径总距离： 3756
# 迭代次数： 263 最佳路径总距离： 3756
# 迭代次数： 264 最佳路径总距离： 3756
# 迭代次数： 265 最佳路径总距离： 3756
# 迭代次数： 266 最佳路径总距离： 3756
# 迭代次数： 267 最佳路径总距离： 3756
# 迭代次数： 268 最佳路径总距离： 3756
# 迭代次数： 269 最佳路径总距离： 3756
# 迭代次数： 270 最佳路径总距离： 3756
# 迭代次数： 271 最佳路径总距离： 3756
# 迭代次数： 272 最佳路径总距离： 3756
# 迭代次数： 273 最佳路径总距离： 3756
# 迭代次数： 274 最佳路径总距离： 3756
# 迭代次数： 275 最佳路径总距离： 3756
# 迭代次数： 276 最佳路径总距离： 3756
# 迭代次数： 277 最佳路径总距离： 3756
# 迭代次数： 278 最佳路径总距离： 3756
# 迭代次数： 279 最佳路径总距离： 3756
# 迭代次数： 280 最佳路径总距离： 3756
# 迭代次数： 281 最佳路径总距离： 3756
# 迭代次数： 282 最佳路径总距离： 3756
# 迭代次数： 283 最佳路径总距离： 3756
# 迭代次数： 284 最佳路径总距离： 3756
# 迭代次数： 285 最佳路径总距离： 3756
# 迭代次数： 286 最佳路径总距离： 3756
# 迭代次数： 287 最佳路径总距离： 3756
# 迭代次数： 288 最佳路径总距离： 3756
# 迭代次数： 289 最佳路径总距离： 3756
# 迭代次数： 290 最佳路径总距离： 3756
# 迭代次数： 291 最佳路径总距离： 3756
# 迭代次数： 292 最佳路径总距离： 3756
# 迭代次数： 293 最佳路径总距离： 3756
# 迭代次数： 294 最佳路径总距离： 3756
# 迭代次数： 295 最佳路径总距离： 3756
# 迭代次数： 296 最佳路径总距离： 3756
# 迭代次数： 297 最佳路径总距离： 3756
# 迭代次数： 298 最佳路径总距离： 3756
# 迭代次数： 299 最佳路径总距离： 3756
# 迭代次数： 300 最佳路径总距离： 3756
# 迭代次数： 301 最佳路径总距离： 3756
# 迭代次数： 302 最佳路径总距离： 3756
# 迭代次数： 303 最佳路径总距离： 3756
# 迭代次数： 304 最佳路径总距离： 3756
# 迭代次数： 305 最佳路径总距离： 3756
# 迭代次数： 306 最佳路径总距离： 3756
# 迭代次数： 307 最佳路径总距离： 3756
# 迭代次数： 308 最佳路径总距离： 3756
# 迭代次数： 309 最佳路径总距离： 3756
# 迭代次数： 310 最佳路径总距离： 3756
# 迭代次数： 311 最佳路径总距离： 3756
# 迭代次数： 312 最佳路径总距离： 3756
# 迭代次数： 313 最佳路径总距离： 3756
# 迭代次数： 314 最佳路径总距离： 3756
# 迭代次数： 315 最佳路径总距离： 3756
# 迭代次数： 316 最佳路径总距离： 3756
# 迭代次数： 317 最佳路径总距离： 3756
# 迭代次数： 318 最佳路径总距离： 3756
# 迭代次数： 319 最佳路径总距离： 3756
# 迭代次数： 320 最佳路径总距离： 3756
# 迭代次数： 321 最佳路径总距离： 3756
# 迭代次数： 322 最佳路径总距离： 3756
# 迭代次数： 323 最佳路径总距离： 3756
# 迭代次数： 324 最佳路径总距离： 3688
# 迭代次数： 325 最佳路径总距离： 3688
# 迭代次数： 326 最佳路径总距离： 3688
# 迭代次数： 327 最佳路径总距离： 3688
# 迭代次数： 328 最佳路径总距离： 3688
# 迭代次数： 329 最佳路径总距离： 3688
# 迭代次数： 330 最佳路径总距离： 3688
# 迭代次数： 331 最佳路径总距离： 3688
# 迭代次数： 332 最佳路径总距离： 3688
# 迭代次数： 333 最佳路径总距离： 3688
# 迭代次数： 334 最佳路径总距离： 3688
# 迭代次数： 335 最佳路径总距离： 3688
# 迭代次数： 336 最佳路径总距离： 3688
# 迭代次数： 337 最佳路径总距离： 3688
# 迭代次数： 338 最佳路径总距离： 3688
# 迭代次数： 339 最佳路径总距离： 3688
# 迭代次数： 340 最佳路径总距离： 3688
# 迭代次数： 341 最佳路径总距离： 3688
# 迭代次数： 342 最佳路径总距离： 3688
# 迭代次数： 343 最佳路径总距离： 3688
# 迭代次数： 344 最佳路径总距离： 3688
# 迭代次数： 345 最佳路径总距离： 3688
# 迭代次数： 346 最佳路径总距离： 3688
# 迭代次数： 347 最佳路径总距离： 3688
# 迭代次数： 348 最佳路径总距离： 3688
# 迭代次数： 349 最佳路径总距离： 3688
# 迭代次数： 350 最佳路径总距离： 3688
# 迭代次数： 351 最佳路径总距离： 3688
# 迭代次数： 352 最佳路径总距离： 3688
# 迭代次数： 353 最佳路径总距离： 3688
# 迭代次数： 354 最佳路径总距离： 3688
# 迭代次数： 355 最佳路径总距离： 3688
# 迭代次数： 356 最佳路径总距离： 3688
# 迭代次数： 357 最佳路径总距离： 3688
# 迭代次数： 358 最佳路径总距离： 3688
# 迭代次数： 359 最佳路径总距离： 3688
# 迭代次数： 360 最佳路径总距离： 3688
# 迭代次数： 361 最佳路径总距离： 3688
# 迭代次数： 362 最佳路径总距离： 3688
# 迭代次数： 363 最佳路径总距离： 3688
# 迭代次数： 364 最佳路径总距离： 3688
# 迭代次数： 365 最佳路径总距离： 3688
# 迭代次数： 366 最佳路径总距离： 3688
# 迭代次数： 367 最佳路径总距离： 3688
# 迭代次数： 368 最佳路径总距离： 3688
# 迭代次数： 369 最佳路径总距离： 3688
# 迭代次数： 370 最佳路径总距离： 3688
# 迭代次数： 371 最佳路径总距离： 3688
# 迭代次数： 372 最佳路径总距离： 3688
# 迭代次数： 373 最佳路径总距离： 3688
# 迭代次数： 374 最佳路径总距离： 3688
# 迭代次数： 375 最佳路径总距离： 3688
# 迭代次数： 376 最佳路径总距离： 3688
# 迭代次数： 377 最佳路径总距离： 3688
# 迭代次数： 378 最佳路径总距离： 3688
# 迭代次数： 379 最佳路径总距离： 3688
# 迭代次数： 380 最佳路径总距离： 3688
# 迭代次数： 381 最佳路径总距离： 3688
# 迭代次数： 382 最佳路径总距离： 3688
# 迭代次数： 383 最佳路径总距离： 3688
# 迭代次数： 384 最佳路径总距离： 3688
# 迭代次数： 385 最佳路径总距离： 3688
# 迭代次数： 386 最佳路径总距离： 3688
# 迭代次数： 387 最佳路径总距离： 3688
# 迭代次数： 388 最佳路径总距离： 3688
# 迭代次数： 389 最佳路径总距离： 3688
# 迭代次数： 390 最佳路径总距离： 3688
# 迭代次数： 391 最佳路径总距离： 3688
# 迭代次数： 392 最佳路径总距离： 3688
# 迭代次数： 393 最佳路径总距离： 3688
# 迭代次数： 394 最佳路径总距离： 3688
# 迭代次数： 395 最佳路径总距离： 3688
# 迭代次数： 396 最佳路径总距离： 3688
# 迭代次数： 397 最佳路径总距离： 3688
# 迭代次数： 398 最佳路径总距离： 3688
# 迭代次数： 399 最佳路径总距离： 3688
# 迭代次数： 400 最佳路径总距离： 3688
# 迭代次数： 401 最佳路径总距离： 3688
# 迭代次数： 402 最佳路径总距离： 3688
# 迭代次数： 403 最佳路径总距离： 3688
# 迭代次数： 404 最佳路径总距离： 3688
# 迭代次数： 405 最佳路径总距离： 3688
# 迭代次数： 406 最佳路径总距离： 3688
# 迭代次数： 407 最佳路径总距离： 3688
# 迭代次数： 408 最佳路径总距离： 3688
# 迭代次数： 409 最佳路径总距离： 3688
# 迭代次数： 410 最佳路径总距离： 3688
# 迭代次数： 411 最佳路径总距离： 3688
# 迭代次数： 412 最佳路径总距离： 3688
# 迭代次数： 413 最佳路径总距离： 3688
# 迭代次数： 414 最佳路径总距离： 3688
# 迭代次数： 415 最佳路径总距离： 3688
# 迭代次数： 416 最佳路径总距离： 3688
# 迭代次数： 417 最佳路径总距离： 3688
# 迭代次数： 418 最佳路径总距离： 3688
# 迭代次数： 419 最佳路径总距离： 3688
# 迭代次数： 420 最佳路径总距离： 3688
# 迭代次数： 421 最佳路径总距离： 3688
# 迭代次数： 422 最佳路径总距离： 3688
# 迭代次数： 423 最佳路径总距离： 3688
# 迭代次数： 424 最佳路径总距离： 3688
# 迭代次数： 425 最佳路径总距离： 3688
# 迭代次数： 426 最佳路径总距离： 3688
# 迭代次数： 427 最佳路径总距离： 3688
# 迭代次数： 428 最佳路径总距离： 3688
# 迭代次数： 429 最佳路径总距离： 3688
# 迭代次数： 430 最佳路径总距离： 3688
# 迭代次数： 431 最佳路径总距离： 3688
# 迭代次数： 432 最佳路径总距离： 3688
# 迭代次数： 433 最佳路径总距离： 3688
# 迭代次数： 434 最佳路径总距离： 3688
# 迭代次数： 435 最佳路径总距离： 3688
# 迭代次数： 436 最佳路径总距离： 3688
# 迭代次数： 437 最佳路径总距离： 3688
# 迭代次数： 438 最佳路径总距离： 3688
# 迭代次数： 439 最佳路径总距离： 3688
# 迭代次数： 440 最佳路径总距离： 3688
# 迭代次数： 441 最佳路径总距离： 3688
# 迭代次数： 442 最佳路径总距离： 3688
# 迭代次数： 443 最佳路径总距离： 3688
# 迭代次数： 444 最佳路径总距离： 3688
# 迭代次数： 445 最佳路径总距离： 3688
# 迭代次数： 446 最佳路径总距离： 3688
# 迭代次数： 447 最佳路径总距离： 3688
# 迭代次数： 448 最佳路径总距离： 3688
# 迭代次数： 449 最佳路径总距离： 3688
# 迭代次数： 450 最佳路径总距离： 3688
# 迭代次数： 451 最佳路径总距离： 3688
# 迭代次数： 452 最佳路径总距离： 3688
# 迭代次数： 453 最佳路径总距离： 3688
# 迭代次数： 454 最佳路径总距离： 3688
# 迭代次数： 455 最佳路径总距离： 3688
# 迭代次数： 456 最佳路径总距离： 3688
# 迭代次数： 457 最佳路径总距离： 3688
# 迭代次数： 458 最佳路径总距离： 3688
# 迭代次数： 459 最佳路径总距离： 3688
# 迭代次数： 460 最佳路径总距离： 3688
# 迭代次数： 461 最佳路径总距离： 3688
# 迭代次数： 462 最佳路径总距离： 3688
# 迭代次数： 463 最佳路径总距离： 3688
# 迭代次数： 464 最佳路径总距离： 3688
# 迭代次数： 465 最佳路径总距离： 3688
# 迭代次数： 466 最佳路径总距离： 3688
# 迭代次数： 467 最佳路径总距离： 3688
# 迭代次数： 468 最佳路径总距离： 3688
# 迭代次数： 469 最佳路径总距离： 3688
# 迭代次数： 470 最佳路径总距离： 3688
# 迭代次数： 471 最佳路径总距离： 3688
# 迭代次数： 472 最佳路径总距离： 3688
# 迭代次数： 473 最佳路径总距离： 3688
# 迭代次数： 474 最佳路径总距离： 3688
# 迭代次数： 475 最佳路径总距离： 3688
# 迭代次数： 476 最佳路径总距离： 3688
# 迭代次数： 477 最佳路径总距离： 3688
# 迭代次数： 478 最佳路径总距离： 3688
# 迭代次数： 479 最佳路径总距离： 3688
# 迭代次数： 480 最佳路径总距离： 3688
# 迭代次数： 481 最佳路径总距离： 3688
# 迭代次数： 482 最佳路径总距离： 3688
# 迭代次数： 483 最佳路径总距离： 3688
# 迭代次数： 484 最佳路径总距离： 3688
# 迭代次数： 485 最佳路径总距离： 3688
# 迭代次数： 486 最佳路径总距离： 3688
# 迭代次数： 487 最佳路径总距离： 3688
# 迭代次数： 488 最佳路径总距离： 3688
# 迭代次数： 489 最佳路径总距离： 3688
# 迭代次数： 490 最佳路径总距离： 3688
# 迭代次数： 491 最佳路径总距离： 3688
# 迭代次数： 492 最佳路径总距离： 3688
# 迭代次数： 493 最佳路径总距离： 3688
# 迭代次数： 494 最佳路径总距离： 3688
# 迭代次数： 495 最佳路径总距离： 3688
# 迭代次数： 496 最佳路径总距离： 3688
# 迭代次数： 497 最佳路径总距离： 3688
# 迭代次数： 498 最佳路径总距离： 3688
# 迭代次数： 499 最佳路径总距离： 3688
# 迭代次数： 500 最佳路径总距离： 3688
# 迭代次数： 501 最佳路径总距离： 3688
# 迭代次数： 502 最佳路径总距离： 3688
# 迭代次数： 503 最佳路径总距离： 3688
# 迭代次数： 504 最佳路径总距离： 3688
# 迭代次数： 505 最佳路径总距离： 3688
# 迭代次数： 506 最佳路径总距离： 3688
# 迭代次数： 507 最佳路径总距离： 3688
# 迭代次数： 508 最佳路径总距离： 3688
# 迭代次数： 509 最佳路径总距离： 3688
# 迭代次数： 510 最佳路径总距离： 3688
# 迭代次数： 511 最佳路径总距离： 3688
# 迭代次数： 512 最佳路径总距离： 3688
# 迭代次数： 513 最佳路径总距离： 3688
# 迭代次数： 514 最佳路径总距离： 3688
# 迭代次数： 515 最佳路径总距离： 3688
# 迭代次数： 516 最佳路径总距离： 3688
# 迭代次数： 517 最佳路径总距离： 3688
# 迭代次数： 518 最佳路径总距离： 3688
# 迭代次数： 519 最佳路径总距离： 3688
# 迭代次数： 520 最佳路径总距离： 3688
# 迭代次数： 521 最佳路径总距离： 3688
# 迭代次数： 522 最佳路径总距离： 3688
# 迭代次数： 523 最佳路径总距离： 3688
# 迭代次数： 524 最佳路径总距离： 3688
# 迭代次数： 525 最佳路径总距离： 3688
# 迭代次数： 526 最佳路径总距离： 3688
# 迭代次数： 527 最佳路径总距离： 3688
# 迭代次数： 528 最佳路径总距离： 3688
# 迭代次数： 529 最佳路径总距离： 3688
# 迭代次数： 530 最佳路径总距离： 3688
# 迭代次数： 531 最佳路径总距离： 3688
# 迭代次数： 532 最佳路径总距离： 3688
# 迭代次数： 533 最佳路径总距离： 3688
# 迭代次数： 534 最佳路径总距离： 3688
# 迭代次数： 535 最佳路径总距离： 3688
# 迭代次数： 536 最佳路径总距离： 3688
# 迭代次数： 537 最佳路径总距离： 3688
# 迭代次数： 538 最佳路径总距离： 3688
# 迭代次数： 539 最佳路径总距离： 3688
# 迭代次数： 540 最佳路径总距离： 3688
# 迭代次数： 541 最佳路径总距离： 3688
# 迭代次数： 542 最佳路径总距离： 3688
# 迭代次数： 543 最佳路径总距离： 3688
# 迭代次数： 544 最佳路径总距离： 3688
# 迭代次数： 545 最佳路径总距离： 3688
# 迭代次数： 546 最佳路径总距离： 3688
# 迭代次数： 547 最佳路径总距离： 3688
# 迭代次数： 548 最佳路径总距离： 3688
# 迭代次数： 549 最佳路径总距离： 3688
# 迭代次数： 550 最佳路径总距离： 3688
# 迭代次数： 551 最佳路径总距离： 3688
# 迭代次数： 552 最佳路径总距离： 3688
# 迭代次数： 553 最佳路径总距离： 3688
# 迭代次数： 554 最佳路径总距离： 3688
# 迭代次数： 555 最佳路径总距离： 3688
# 迭代次数： 556 最佳路径总距离： 3688
# 迭代次数： 557 最佳路径总距离： 3688
# 迭代次数： 558 最佳路径总距离： 3688
# 迭代次数： 559 最佳路径总距离： 3688
# 迭代次数： 560 最佳路径总距离： 3688
# 迭代次数： 561 最佳路径总距离： 3688
# 迭代次数： 562 最佳路径总距离： 3688
# 迭代次数： 563 最佳路径总距离： 3688
# 迭代次数： 564 最佳路径总距离： 3688
# 迭代次数： 565 最佳路径总距离： 3688
# 迭代次数： 566 最佳路径总距离： 3688
# 迭代次数： 567 最佳路径总距离： 3688
# 迭代次数： 568 最佳路径总距离： 3688
# 迭代次数： 569 最佳路径总距离： 3688
# 迭代次数： 570 最佳路径总距离： 3688
# 迭代次数： 571 最佳路径总距离： 3688
# 迭代次数： 572 最佳路径总距离： 3688
# 迭代次数： 573 最佳路径总距离： 3688
# 迭代次数： 574 最佳路径总距离： 3688
# 迭代次数： 575 最佳路径总距离： 3688
# 迭代次数： 576 最佳路径总距离： 3688
# 迭代次数： 577 最佳路径总距离： 3688
# 迭代次数： 578 最佳路径总距离： 3688
# 迭代次数： 579 最佳路径总距离： 3688
# 迭代次数： 580 最佳路径总距离： 3688
# 迭代次数： 581 最佳路径总距离： 3688
# 迭代次数： 582 最佳路径总距离： 3688
# 迭代次数： 583 最佳路径总距离： 3688
# 迭代次数： 584 最佳路径总距离： 3688
# 迭代次数： 585 最佳路径总距离： 3688
# 迭代次数： 586 最佳路径总距离： 3688
# 迭代次数： 587 最佳路径总距离： 3688
# 迭代次数： 588 最佳路径总距离： 3688
# 迭代次数： 589 最佳路径总距离： 3688
# 迭代次数： 590 最佳路径总距离： 3688
# 迭代次数： 591 最佳路径总距离： 3688
# 迭代次数： 592 最佳路径总距离： 3688
# 迭代次数： 593 最佳路径总距离： 3688
# 迭代次数： 594 最佳路径总距离： 3688
# 迭代次数： 595 最佳路径总距离： 3688
# 迭代次数： 596 最佳路径总距离： 3688
# 迭代次数： 597 最佳路径总距离： 3688
# 迭代次数： 598 最佳路径总距离： 3688
# 迭代次数： 599 最佳路径总距离： 3688
# 迭代次数： 600 最佳路径总距离： 3688
# 迭代次数： 601 最佳路径总距离： 3688
# 迭代次数： 602 最佳路径总距离： 3688
# 迭代次数： 603 最佳路径总距离： 3688
# 迭代次数： 604 最佳路径总距离： 3688
# 迭代次数： 605 最佳路径总距离： 3688
# 迭代次数： 606 最佳路径总距离： 3688
# 迭代次数： 607 最佳路径总距离： 3688
# 迭代次数： 608 最佳路径总距离： 3688
# 迭代次数： 609 最佳路径总距离： 3688
# 迭代次数： 610 最佳路径总距离： 3688
# 迭代次数： 611 最佳路径总距离： 3688
# 迭代次数： 612 最佳路径总距离： 3688
# 迭代次数： 613 最佳路径总距离： 3688
# 迭代次数： 614 最佳路径总距离： 3688
# 迭代次数： 615 最佳路径总距离： 3688
# 迭代次数： 616 最佳路径总距离： 3688
# 迭代次数： 617 最佳路径总距离： 3688
# 迭代次数： 618 最佳路径总距离： 3688
# 迭代次数： 619 最佳路径总距离： 3688
# 迭代次数： 620 最佳路径总距离： 3688
# 迭代次数： 621 最佳路径总距离： 3688
# 迭代次数： 622 最佳路径总距离： 3688
# 迭代次数： 623 最佳路径总距离： 3688
# 迭代次数： 624 最佳路径总距离： 3688
# 迭代次数： 625 最佳路径总距离： 3688
# 迭代次数： 626 最佳路径总距离： 3688
# 迭代次数： 627 最佳路径总距离： 3688
# 迭代次数： 628 最佳路径总距离： 3688
# 迭代次数： 629 最佳路径总距离： 3688
# 迭代次数： 630 最佳路径总距离： 3688
# 迭代次数： 631 最佳路径总距离： 3688
# 迭代次数： 632 最佳路径总距离： 3688
# 迭代次数： 633 最佳路径总距离： 3688
# 迭代次数： 634 最佳路径总距离： 3688
# 迭代次数： 635 最佳路径总距离： 3688
# 迭代次数： 636 最佳路径总距离： 3688
# 迭代次数： 637 最佳路径总距离： 3688
# 迭代次数： 638 最佳路径总距离： 3688
# 迭代次数： 639 最佳路径总距离： 3688
# 迭代次数： 640 最佳路径总距离： 3688
# 迭代次数： 641 最佳路径总距离： 3688
# 迭代次数： 642 最佳路径总距离： 3688
# 迭代次数： 643 最佳路径总距离： 3688
# 迭代次数： 644 最佳路径总距离： 3688
# 迭代次数： 645 最佳路径总距离： 3688
# 迭代次数： 646 最佳路径总距离： 3688
# 迭代次数： 647 最佳路径总距离： 3688
# 迭代次数： 648 最佳路径总距离： 3688
# 迭代次数： 649 最佳路径总距离： 3688
# 迭代次数： 650 最佳路径总距离： 3688
# 迭代次数： 651 最佳路径总距离： 3688
# 迭代次数： 652 最佳路径总距离： 3688
# 迭代次数： 653 最佳路径总距离： 3688
# 迭代次数： 654 最佳路径总距离： 3688
# 迭代次数： 655 最佳路径总距离： 3688
# 迭代次数： 656 最佳路径总距离： 3688
# 迭代次数： 657 最佳路径总距离： 3688
# 迭代次数： 658 最佳路径总距离： 3688
# 迭代次数： 659 最佳路径总距离： 3688
# 迭代次数： 660 最佳路径总距离： 3688
# 迭代次数： 661 最佳路径总距离： 3688
# 迭代次数： 662 最佳路径总距离： 3688
# 迭代次数： 663 最佳路径总距离： 3688
# 迭代次数： 664 最佳路径总距离： 3688
# 迭代次数： 665 最佳路径总距离： 3688
# 迭代次数： 666 最佳路径总距离： 3688
# 迭代次数： 667 最佳路径总距离： 3688
# 迭代次数： 668 最佳路径总距离： 3688
# 迭代次数： 669 最佳路径总距离： 3688
# 迭代次数： 670 最佳路径总距离： 3688
# 迭代次数： 671 最佳路径总距离： 3688
# 迭代次数： 672 最佳路径总距离： 3688
# 迭代次数： 673 最佳路径总距离： 3688
# 迭代次数： 674 最佳路径总距离： 3688
# 迭代次数： 675 最佳路径总距离： 3688
# 迭代次数： 676 最佳路径总距离： 3688
# 迭代次数： 677 最佳路径总距离： 3688
# 迭代次数： 678 最佳路径总距离： 3688
# 迭代次数： 679 最佳路径总距离： 3688
# 迭代次数： 680 最佳路径总距离： 3688
# 迭代次数： 681 最佳路径总距离： 3688
# 迭代次数： 682 最佳路径总距离： 3688
# 迭代次数： 683 最佳路径总距离： 3688
# 迭代次数： 684 最佳路径总距离： 3688
# 迭代次数： 685 最佳路径总距离： 3688
# 迭代次数： 686 最佳路径总距离： 3688
# 迭代次数： 687 最佳路径总距离： 3688
# 迭代次数： 688 最佳路径总距离： 3688
# 迭代次数： 689 最佳路径总距离： 3688
# 迭代次数： 690 最佳路径总距离： 3688
# 迭代次数： 691 最佳路径总距离： 3688
# 迭代次数： 692 最佳路径总距离： 3688
# 迭代次数： 693 最佳路径总距离： 3688
# 迭代次数： 694 最佳路径总距离： 3688
# 迭代次数： 695 最佳路径总距离： 3688
# 迭代次数： 696 最佳路径总距离： 3688
# 迭代次数： 697 最佳路径总距离： 3688
# 迭代次数： 698 最佳路径总距离： 3688
# 迭代次数： 699 最佳路径总距离： 3688
# 迭代次数： 700 最佳路径总距离： 3688
# 迭代次数： 701 最佳路径总距离： 3688
# 迭代次数： 702 最佳路径总距离： 3688
# 迭代次数： 703 最佳路径总距离： 3688
# 迭代次数： 704 最佳路径总距离： 3688
# 迭代次数： 705 最佳路径总距离： 3688
# 迭代次数： 706 最佳路径总距离： 3688
# 迭代次数： 707 最佳路径总距离： 3688
# 迭代次数： 708 最佳路径总距离： 3688
# 迭代次数： 709 最佳路径总距离： 3688
# 迭代次数： 710 最佳路径总距离： 3688
# 迭代次数： 711 最佳路径总距离： 3688
# 迭代次数： 712 最佳路径总距离： 3688
# 迭代次数： 713 最佳路径总距离： 3688
# 迭代次数： 714 最佳路径总距离： 3688
# 迭代次数： 715 最佳路径总距离： 3688
# 迭代次数： 716 最佳路径总距离： 3688
# 迭代次数： 717 最佳路径总距离： 3688
# 迭代次数： 718 最佳路径总距离： 3688
# 迭代次数： 719 最佳路径总距离： 3688
# 迭代次数： 720 最佳路径总距离： 3688
# 迭代次数： 721 最佳路径总距离： 3688
# 迭代次数： 722 最佳路径总距离： 3688
# 迭代次数： 723 最佳路径总距离： 3688
# 迭代次数： 724 最佳路径总距离： 3688
# 迭代次数： 725 最佳路径总距离： 3688
# 迭代次数： 726 最佳路径总距离： 3688
# 迭代次数： 727 最佳路径总距离： 3688
# 迭代次数： 728 最佳路径总距离： 3688
# 迭代次数： 729 最佳路径总距离： 3688
# 迭代次数： 730 最佳路径总距离： 3688
# 迭代次数： 731 最佳路径总距离： 3688
# 迭代次数： 732 最佳路径总距离： 3688
# 迭代次数： 733 最佳路径总距离： 3688
# 迭代次数： 734 最佳路径总距离： 3688
# 迭代次数： 735 最佳路径总距离： 3688
# 迭代次数： 736 最佳路径总距离： 3688
# 迭代次数： 737 最佳路径总距离： 3688
# 迭代次数： 738 最佳路径总距离： 3688
# 迭代次数： 739 最佳路径总距离： 3688
# 迭代次数： 740 最佳路径总距离： 3688
# 迭代次数： 741 最佳路径总距离： 3688
# 迭代次数： 742 最佳路径总距离： 3688
# 迭代次数： 743 最佳路径总距离： 3688
# 迭代次数： 744 最佳路径总距离： 3688
# 迭代次数： 745 最佳路径总距离： 3688
# 迭代次数： 746 最佳路径总距离： 3688
# 迭代次数： 747 最佳路径总距离： 3688
# 迭代次数： 748 最佳路径总距离： 3688
# 迭代次数： 749 最佳路径总距离： 3688
# 迭代次数： 750 最佳路径总距离： 3688
# 迭代次数： 751 最佳路径总距离： 3688
# 迭代次数： 752 最佳路径总距离： 3688
# 迭代次数： 753 最佳路径总距离： 3688
# 迭代次数： 754 最佳路径总距离： 3688
# 迭代次数： 755 最佳路径总距离： 3688
# 迭代次数： 756 最佳路径总距离： 3688
# 迭代次数： 757 最佳路径总距离： 3688
# 迭代次数： 758 最佳路径总距离： 3688
# 迭代次数： 759 最佳路径总距离： 3688
# 迭代次数： 760 最佳路径总距离： 3688
# 迭代次数： 761 最佳路径总距离： 3688
# 迭代次数： 762 最佳路径总距离： 3688
# 迭代次数： 763 最佳路径总距离： 3688
# 迭代次数： 764 最佳路径总距离： 3688
# 迭代次数： 765 最佳路径总距离： 3688
# 迭代次数： 766 最佳路径总距离： 3688
# 迭代次数： 767 最佳路径总距离： 3688
# 迭代次数： 768 最佳路径总距离： 3688
# 迭代次数： 769 最佳路径总距离： 3688
# 迭代次数： 770 最佳路径总距离： 3688
# 迭代次数： 771 最佳路径总距离： 3688
# 迭代次数： 772 最佳路径总距离： 3688
# 迭代次数： 773 最佳路径总距离： 3688
# 迭代次数： 774 最佳路径总距离： 3688
# 迭代次数： 775 最佳路径总距离： 3688
# 迭代次数： 776 最佳路径总距离： 3688
# 迭代次数： 777 最佳路径总距离： 3688
# 迭代次数： 778 最佳路径总距离： 3688
# 迭代次数： 779 最佳路径总距离： 3688
# 迭代次数： 780 最佳路径总距离： 3688
# 迭代次数： 781 最佳路径总距离： 3688
# 迭代次数： 782 最佳路径总距离： 3688
# 迭代次数： 783 最佳路径总距离： 3688
# 迭代次数： 784 最佳路径总距离： 3688
# 迭代次数： 785 最佳路径总距离： 3688
# 迭代次数： 786 最佳路径总距离： 3688
# 迭代次数： 787 最佳路径总距离： 3688
# 迭代次数： 788 最佳路径总距离： 3688
# 迭代次数： 789 最佳路径总距离： 3688
# 迭代次数： 790 最佳路径总距离： 3688
# 迭代次数： 791 最佳路径总距离： 3688
# 迭代次数： 792 最佳路径总距离： 3688
# 迭代次数： 793 最佳路径总距离： 3688
# 迭代次数： 794 最佳路径总距离： 3688
# 迭代次数： 795 最佳路径总距离： 3688
# 迭代次数： 796 最佳路径总距离： 3688
# 迭代次数： 797 最佳路径总距离： 3688
# 迭代次数： 798 最佳路径总距离： 3688
# 迭代次数： 799 最佳路径总距离： 3688
# 迭代次数： 800 最佳路径总距离： 3688
# 迭代次数： 801 最佳路径总距离： 3688
# 迭代次数： 802 最佳路径总距离： 3688
# 迭代次数： 803 最佳路径总距离： 3688
# 迭代次数： 804 最佳路径总距离： 3688
# 迭代次数： 805 最佳路径总距离： 3688
# 迭代次数： 806 最佳路径总距离： 3688
# 迭代次数： 807 最佳路径总距离： 3688
# 迭代次数： 808 最佳路径总距离： 3688
# 迭代次数： 809 最佳路径总距离： 3688
# 迭代次数： 810 最佳路径总距离： 3688
# 迭代次数： 811 最佳路径总距离： 3688
# 迭代次数： 812 最佳路径总距离： 3688
# 迭代次数： 813 最佳路径总距离： 3688
# 迭代次数： 814 最佳路径总距离： 3688
# 迭代次数： 815 最佳路径总距离： 3688
# 迭代次数： 816 最佳路径总距离： 3688
# 迭代次数： 817 最佳路径总距离： 3688
# 迭代次数： 818 最佳路径总距离： 3688
# 迭代次数： 819 最佳路径总距离： 3688
# 迭代次数： 820 最佳路径总距离： 3688
# 迭代次数： 821 最佳路径总距离： 3688
# 迭代次数： 822 最佳路径总距离： 3688
# 迭代次数： 823 最佳路径总距离： 3688
# 迭代次数： 824 最佳路径总距离： 3688
# 迭代次数： 825 最佳路径总距离： 3688
# 迭代次数： 826 最佳路径总距离： 3688
# 迭代次数： 827 最佳路径总距离： 3688
# 迭代次数： 828 最佳路径总距离： 3688
# 迭代次数： 829 最佳路径总距离： 3688
# 迭代次数： 830 最佳路径总距离： 3688
# 迭代次数： 831 最佳路径总距离： 3688
# 迭代次数： 832 最佳路径总距离： 3688
# 迭代次数： 833 最佳路径总距离： 3688
# 迭代次数： 834 最佳路径总距离： 3688
# 迭代次数： 835 最佳路径总距离： 3688
# 迭代次数： 836 最佳路径总距离： 3688
# 迭代次数： 837 最佳路径总距离： 3688
# 迭代次数： 838 最佳路径总距离： 3688
# 迭代次数： 839 最佳路径总距离： 3688
# 迭代次数： 840 最佳路径总距离： 3688
# 迭代次数： 841 最佳路径总距离： 3688
# 迭代次数： 842 最佳路径总距离： 3688
# 迭代次数： 843 最佳路径总距离： 3688
# 迭代次数： 844 最佳路径总距离： 3688
# 迭代次数： 845 最佳路径总距离： 3688
# 迭代次数： 846 最佳路径总距离： 3688
# 迭代次数： 847 最佳路径总距离： 3688
# 迭代次数： 848 最佳路径总距离： 3688
# 迭代次数： 849 最佳路径总距离： 3688
# 迭代次数： 850 最佳路径总距离： 3688
# 迭代次数： 851 最佳路径总距离： 3688
# 迭代次数： 852 最佳路径总距离： 3688
# 迭代次数： 853 最佳路径总距离： 3688
# 迭代次数： 854 最佳路径总距离： 3688
# 迭代次数： 855 最佳路径总距离： 3688
# 迭代次数： 856 最佳路径总距离： 3688
# 迭代次数： 857 最佳路径总距离： 3688
# 迭代次数： 858 最佳路径总距离： 3688
# 迭代次数： 859 最佳路径总距离： 3688
# 迭代次数： 860 最佳路径总距离： 3688
# 迭代次数： 861 最佳路径总距离： 3688
# 迭代次数： 862 最佳路径总距离： 3688
# 迭代次数： 863 最佳路径总距离： 3688
# 迭代次数： 864 最佳路径总距离： 3688
# 迭代次数： 865 最佳路径总距离： 3688
# 迭代次数： 866 最佳路径总距离： 3688
# 迭代次数： 867 最佳路径总距离： 3688
# 迭代次数： 868 最佳路径总距离： 3688
# 迭代次数： 869 最佳路径总距离： 3688
# 迭代次数： 870 最佳路径总距离： 3688
# 迭代次数： 871 最佳路径总距离： 3688
# 迭代次数： 872 最佳路径总距离： 3688
# 迭代次数： 873 最佳路径总距离： 3688
# 迭代次数： 874 最佳路径总距离： 3688
# 迭代次数： 875 最佳路径总距离： 3688
# 迭代次数： 876 最佳路径总距离： 3688
# 迭代次数： 877 最佳路径总距离： 3688
# 迭代次数： 878 最佳路径总距离： 3688
# 迭代次数： 879 最佳路径总距离： 3688
# 迭代次数： 880 最佳路径总距离： 3688
# 迭代次数： 881 最佳路径总距离： 3688
# 迭代次数： 882 最佳路径总距离： 3688
# 迭代次数： 883 最佳路径总距离： 3688
# 迭代次数： 884 最佳路径总距离： 3688
# 迭代次数： 885 最佳路径总距离： 3688
# 迭代次数： 886 最佳路径总距离： 3688
# 迭代次数： 887 最佳路径总距离： 3688
# 迭代次数： 888 最佳路径总距离： 3688
# 迭代次数： 889 最佳路径总距离： 3688
# 迭代次数： 890 最佳路径总距离： 3688
# 迭代次数： 891 最佳路径总距离： 3688
# 迭代次数： 892 最佳路径总距离： 3688
# 迭代次数： 893 最佳路径总距离： 3688
# 迭代次数： 894 最佳路径总距离： 3688
# 迭代次数： 895 最佳路径总距离： 3688
# 迭代次数： 896 最佳路径总距离： 3688
# 迭代次数： 897 最佳路径总距离： 3688
# 迭代次数： 898 最佳路径总距离： 3688
# 迭代次数： 899 最佳路径总距离： 3688
# 迭代次数： 900 最佳路径总距离： 3688
# 迭代次数： 901 最佳路径总距离： 3688
# 迭代次数： 902 最佳路径总距离： 3688
# 迭代次数： 903 最佳路径总距离： 3688
# 迭代次数： 904 最佳路径总距离： 3688
# 迭代次数： 905 最佳路径总距离： 3688
# 迭代次数： 906 最佳路径总距离： 3688
# 迭代次数： 907 最佳路径总距离： 3688
# 迭代次数： 908 最佳路径总距离： 3688
# 迭代次数： 909 最佳路径总距离： 3688
# 迭代次数： 910 最佳路径总距离： 3688
# 迭代次数： 911 最佳路径总距离： 3688
# 迭代次数： 912 最佳路径总距离： 3688
# 迭代次数： 913 最佳路径总距离： 3688
# 迭代次数： 914 最佳路径总距离： 3688
# 迭代次数： 915 最佳路径总距离： 3688
# 迭代次数： 916 最佳路径总距离： 3688
# 迭代次数： 917 最佳路径总距离： 3688
# 迭代次数： 918 最佳路径总距离： 3688
# 迭代次数： 919 最佳路径总距离： 3688
# 迭代次数： 920 最佳路径总距离： 3688
# 迭代次数： 921 最佳路径总距离： 3688
# 迭代次数： 922 最佳路径总距离： 3688
# 迭代次数： 923 最佳路径总距离： 3688
# 迭代次数： 924 最佳路径总距离： 3688
# 迭代次数： 925 最佳路径总距离： 3688
# 迭代次数： 926 最佳路径总距离： 3688
# 迭代次数： 927 最佳路径总距离： 3688
# 迭代次数： 928 最佳路径总距离： 3688
# 迭代次数： 929 最佳路径总距离： 3688
# 迭代次数： 930 最佳路径总距离： 3688
# 迭代次数： 931 最佳路径总距离： 3688
# 迭代次数： 932 最佳路径总距离： 3688
# 迭代次数： 933 最佳路径总距离： 3688
# 迭代次数： 934 最佳路径总距离： 3688
# 迭代次数： 935 最佳路径总距离： 3688
# 迭代次数： 936 最佳路径总距离： 3688
# 迭代次数： 937 最佳路径总距离： 3688
# 迭代次数： 938 最佳路径总距离： 3688
# 迭代次数： 939 最佳路径总距离： 3688
# 迭代次数： 940 最佳路径总距离： 3688
# 迭代次数： 941 最佳路径总距离： 3688
# 迭代次数： 942 最佳路径总距离： 3688
# 迭代次数： 943 最佳路径总距离： 3688
# 迭代次数： 944 最佳路径总距离： 3688
# 迭代次数： 945 最佳路径总距离： 3688
# 迭代次数： 946 最佳路径总距离： 3688
# 迭代次数： 947 最佳路径总距离： 3688
# 迭代次数： 948 最佳路径总距离： 3688
# 迭代次数： 949 最佳路径总距离： 3688
# 迭代次数： 950 最佳路径总距离： 3688
# 迭代次数： 951 最佳路径总距离： 3688
# 迭代次数： 952 最佳路径总距离： 3688
# 迭代次数： 953 最佳路径总距离： 3688
# 迭代次数： 954 最佳路径总距离： 3688
# 迭代次数： 955 最佳路径总距离： 3688
# 迭代次数： 956 最佳路径总距离： 3688
# 迭代次数： 957 最佳路径总距离： 3688
# 迭代次数： 958 最佳路径总距离： 3688
# 迭代次数： 959 最佳路径总距离： 3688
# 迭代次数： 960 最佳路径总距离： 3688
# 迭代次数： 961 最佳路径总距离： 3688
# 迭代次数： 962 最佳路径总距离： 3688
# 迭代次数： 963 最佳路径总距离： 3688
# 迭代次数： 964 最佳路径总距离： 3688
# 迭代次数： 965 最佳路径总距离： 3688
# 迭代次数： 966 最佳路径总距离： 3688
# 迭代次数： 967 最佳路径总距离： 3688
# 迭代次数： 968 最佳路径总距离： 3688
# 迭代次数： 969 最佳路径总距离： 3688
# 迭代次数： 970 最佳路径总距离： 3688
# 迭代次数： 971 最佳路径总距离： 3688
# 迭代次数： 972 最佳路径总距离： 3688
# 迭代次数： 973 最佳路径总距离： 3688
# 迭代次数： 974 最佳路径总距离： 3688
# 迭代次数： 975 最佳路径总距离： 3688
# 迭代次数： 976 最佳路径总距离： 3688
# 迭代次数： 977 最佳路径总距离： 3688
# 迭代次数： 978 最佳路径总距离： 3688
# 迭代次数： 979 最佳路径总距离： 3688
# 迭代次数： 980 最佳路径总距离： 3688
# 迭代次数： 981 最佳路径总距离： 3688
# 迭代次数： 982 最佳路径总距离： 3688
# 迭代次数： 983 最佳路径总距离： 3688
# 迭代次数： 984 最佳路径总距离： 3688
# 迭代次数： 985 最佳路径总距离： 3688
# 迭代次数： 986 最佳路径总距离： 3688
# 迭代次数： 987 最佳路径总距离： 3688
# 迭代次数： 988 最佳路径总距离： 3688
# 迭代次数： 989 最佳路径总距离： 3688
# 迭代次数： 990 最佳路径总距离： 3688
# 迭代次数： 991 最佳路径总距离： 3688
# 迭代次数： 992 最佳路径总距离： 3688
# 迭代次数： 993 最佳路径总距离： 3688
# 迭代次数： 994 最佳路径总距离： 3688
# 迭代次数： 995 最佳路径总距离： 3688
# 迭代次数： 996 最佳路径总距离： 3688
# 迭代次数： 997 最佳路径总距离： 3688
# 迭代次数： 998 最佳路径总距离： 3688
# 迭代次数： 999 最佳路径总距离： 3688
# 迭代次数： 1000 最佳路径总距离： 3688
# 迭代次数： 1001 最佳路径总距离： 3688
# 迭代次数： 1002 最佳路径总距离： 3688
# 迭代次数： 1003 最佳路径总距离： 3688
# 迭代次数： 1004 最佳路径总距离： 3688
# 迭代次数： 1005 最佳路径总距离： 3688
# 迭代次数： 1006 最佳路径总距离： 3688
# 迭代次数： 1007 最佳路径总距离： 3688
# 迭代次数： 1008 最佳路径总距离： 3688
# 迭代次数： 1009 最佳路径总距离： 3688
# 迭代次数： 1010 最佳路径总距离： 3688
# 迭代次数： 1011 最佳路径总距离： 3688
# 迭代次数： 1012 最佳路径总距离： 3688
# 迭代次数： 1013 最佳路径总距离： 3688
# 迭代次数： 1014 最佳路径总距离： 3688
# 迭代次数： 1015 最佳路径总距离： 3688
# 迭代次数： 1016 最佳路径总距离： 3688
# 迭代次数： 1017 最佳路径总距离： 3688
# 迭代次数： 1018 最佳路径总距离： 3688
# 迭代次数： 1019 最佳路径总距离： 3688
# 迭代次数： 1020 最佳路径总距离： 3688
# 迭代次数： 1021 最佳路径总距离： 3688
# 迭代次数： 1022 最佳路径总距离： 3688
# 迭代次数： 1023 最佳路径总距离： 3688
# 迭代次数： 1024 最佳路径总距离： 3688
# 迭代次数： 1025 最佳路径总距离： 3688
# 迭代次数： 1026 最佳路径总距离： 3688
# 迭代次数： 1027 最佳路径总距离： 3688
# 迭代次数： 1028 最佳路径总距离： 3688
# 迭代次数： 1029 最佳路径总距离： 3688
# 迭代次数： 1030 最佳路径总距离： 3688
# 迭代次数： 1031 最佳路径总距离： 3688
# 迭代次数： 1032 最佳路径总距离： 3688
# 迭代次数： 1033 最佳路径总距离： 3688
# 迭代次数： 1034 最佳路径总距离： 3688
# 迭代次数： 1035 最佳路径总距离： 3688
# 迭代次数： 1036 最佳路径总距离： 3688
# 迭代次数： 1037 最佳路径总距离： 3688
# 迭代次数： 1038 最佳路径总距离： 3688
# 迭代次数： 1039 最佳路径总距离： 3688
# 迭代次数： 1040 最佳路径总距离： 3688
# 迭代次数： 1041 最佳路径总距离： 3688
# 迭代次数： 1042 最佳路径总距离： 3688
# 迭代次数： 1043 最佳路径总距离： 3688
# 迭代次数： 1044 最佳路径总距离： 3688
# 迭代次数： 1045 最佳路径总距离： 3688
# 迭代次数： 1046 最佳路径总距离： 3688
# 迭代次数： 1047 最佳路径总距离： 3688
# 迭代次数： 1048 最佳路径总距离： 3688
# 迭代次数： 1049 最佳路径总距离： 3688
# 迭代次数： 1050 最佳路径总距离： 3688
# 迭代次数： 1051 最佳路径总距离： 3688
# 迭代次数： 1052 最佳路径总距离： 3688
# 迭代次数： 1053 最佳路径总距离： 3688
# 迭代次数： 1054 最佳路径总距离： 3688
# 迭代次数： 1055 最佳路径总距离： 3688
# 迭代次数： 1056 最佳路径总距离： 3688
# 迭代次数： 1057 最佳路径总距离： 3688
# 迭代次数： 1058 最佳路径总距离： 3688
# 迭代次数： 1059 最佳路径总距离： 3688
# 迭代次数： 1060 最佳路径总距离： 3688
# 迭代次数： 1061 最佳路径总距离： 3688
# 迭代次数： 1062 最佳路径总距离： 3688
# 迭代次数： 1063 最佳路径总距离： 3688
# 迭代次数： 1064 最佳路径总距离： 3688
# 迭代次数： 1065 最佳路径总距离： 3688
# 迭代次数： 1066 最佳路径总距离： 3688
# 迭代次数： 1067 最佳路径总距离： 3688
# 迭代次数： 1068 最佳路径总距离： 3688
# 迭代次数： 1069 最佳路径总距离： 3688
# 迭代次数： 1070 最佳路径总距离： 3688
# 迭代次数： 1071 最佳路径总距离： 3688
# 迭代次数： 1072 最佳路径总距离： 3688
# 迭代次数： 1073 最佳路径总距离： 3688
# 迭代次数： 1074 最佳路径总距离： 3688
# 迭代次数： 1075 最佳路径总距离： 3688
# 迭代次数： 1076 最佳路径总距离： 3688
# 迭代次数： 1077 最佳路径总距离： 3688
# 迭代次数： 1078 最佳路径总距离： 3688
# 迭代次数： 1079 最佳路径总距离： 3688
# 迭代次数： 1080 最佳路径总距离： 3688
# 迭代次数： 1081 最佳路径总距离： 3688
# 迭代次数： 1082 最佳路径总距离： 3688
# 迭代次数： 1083 最佳路径总距离： 3688
# 迭代次数： 1084 最佳路径总距离： 3688
# 迭代次数： 1085 最佳路径总距离： 3688
# 迭代次数： 1086 最佳路径总距离： 3688
# 迭代次数： 1087 最佳路径总距离： 3688
# 迭代次数： 1088 最佳路径总距离： 3688
# 迭代次数： 1089 最佳路径总距离： 3688
# 迭代次数： 1090 最佳路径总距离： 3688
# 迭代次数： 1091 最佳路径总距离： 3688
# 迭代次数： 1092 最佳路径总距离： 3688
# 迭代次数： 1093 最佳路径总距离： 3688
# 迭代次数： 1094 最佳路径总距离： 3688
# 迭代次数： 1095 最佳路径总距离： 3688
# 迭代次数： 1096 最佳路径总距离： 3688
# 迭代次数： 1097 最佳路径总距离： 3688
# 迭代次数： 1098 最佳路径总距离： 3688
# 迭代次数： 1099 最佳路径总距离： 3688
# 迭代次数： 1100 最佳路径总距离： 3688
# 迭代次数： 1101 最佳路径总距离： 3688
# 迭代次数： 1102 最佳路径总距离： 3688
# 迭代次数： 1103 最佳路径总距离： 3688
# 迭代次数： 1104 最佳路径总距离： 3688
# 迭代次数： 1105 最佳路径总距离： 3688
# 迭代次数： 1106 最佳路径总距离： 3688
# 迭代次数： 1107 最佳路径总距离： 3688
# 迭代次数： 1108 最佳路径总距离： 3688
# 迭代次数： 1109 最佳路径总距离： 3688
# 迭代次数： 1110 最佳路径总距离： 3688
# 迭代次数： 1111 最佳路径总距离： 3688
# 迭代次数： 1112 最佳路径总距离： 3688
# 迭代次数： 1113 最佳路径总距离： 3688
# 迭代次数： 1114 最佳路径总距离： 3688
# 迭代次数： 1115 最佳路径总距离： 3688
# 迭代次数： 1116 最佳路径总距离： 3688
# 迭代次数： 1117 最佳路径总距离： 3688
# 迭代次数： 1118 最佳路径总距离： 3688
# 迭代次数： 1119 最佳路径总距离： 3688
# 迭代次数： 1120 最佳路径总距离： 3688
# 迭代次数： 1121 最佳路径总距离： 3688
# 迭代次数： 1122 最佳路径总距离： 3688
# 迭代次数： 1123 最佳路径总距离： 3688
# 迭代次数： 1124 最佳路径总距离： 3688
# 迭代次数： 1125 最佳路径总距离： 3688
# 迭代次数： 1126 最佳路径总距离： 3688
# 迭代次数： 1127 最佳路径总距离： 3688
# 迭代次数： 1128 最佳路径总距离： 3688
# 迭代次数： 1129 最佳路径总距离： 3688
# 迭代次数： 1130 最佳路径总距离： 3688
# 迭代次数： 1131 最佳路径总距离： 3688
# 迭代次数： 1132 最佳路径总距离： 3688
# 迭代次数： 1133 最佳路径总距离： 3688
# 迭代次数： 1134 最佳路径总距离： 3688
# 迭代次数： 1135 最佳路径总距离： 3688
# 迭代次数： 1136 最佳路径总距离： 3688
# 迭代次数： 1137 最佳路径总距离： 3688
# 迭代次数： 1138 最佳路径总距离： 3688
# 迭代次数： 1139 最佳路径总距离： 3688
# 迭代次数： 1140 最佳路径总距离： 3688
# 迭代次数： 1141 最佳路径总距离： 3688
# 迭代次数： 1142 最佳路径总距离： 3688
# 迭代次数： 1143 最佳路径总距离： 3688
# 迭代次数： 1144 最佳路径总距离： 3688
# 迭代次数： 1145 最佳路径总距离： 3688
# 迭代次数： 1146 最佳路径总距离： 3688
# 迭代次数： 1147 最佳路径总距离： 3688
# 迭代次数： 1148 最佳路径总距离： 3688
# 迭代次数： 1149 最佳路径总距离： 3688
# 迭代次数： 1150 最佳路径总距离： 3688
# 迭代次数： 1151 最佳路径总距离： 3688
# 迭代次数： 1152 最佳路径总距离： 3688
# 迭代次数： 1153 最佳路径总距离： 3688
# 迭代次数： 1154 最佳路径总距离： 3688
# 迭代次数： 1155 最佳路径总距离： 3688
# 迭代次数： 1156 最佳路径总距离： 3688
# 迭代次数： 1157 最佳路径总距离： 3688
# 迭代次数： 1158 最佳路径总距离： 3688
# 迭代次数： 1159 最佳路径总距离： 3688
# 迭代次数： 1160 最佳路径总距离： 3688
# 迭代次数： 1161 最佳路径总距离： 3688
# 迭代次数： 1162 最佳路径总距离： 3688
# 迭代次数： 1163 最佳路径总距离： 3688
# 迭代次数： 1164 最佳路径总距离： 3688
# 迭代次数： 1165 最佳路径总距离： 3688
# 迭代次数： 1166 最佳路径总距离： 3688
# 迭代次数： 1167 最佳路径总距离： 3688
# 迭代次数： 1168 最佳路径总距离： 3688
# 迭代次数： 1169 最佳路径总距离： 3688
# 迭代次数： 1170 最佳路径总距离： 3688
# 迭代次数： 1171 最佳路径总距离： 3688
# 迭代次数： 1172 最佳路径总距离： 3688
# 迭代次数： 1173 最佳路径总距离： 3688
# 迭代次数： 1174 最佳路径总距离： 3688
# 迭代次数： 1175 最佳路径总距离： 3688
# 迭代次数： 1176 最佳路径总距离： 3688
# 迭代次数： 1177 最佳路径总距离： 3688
# 迭代次数： 1178 最佳路径总距离： 3688
# 迭代次数： 1179 最佳路径总距离： 3688
# 迭代次数： 1180 最佳路径总距离： 3688
# 迭代次数： 1181 最佳路径总距离： 3688
# 迭代次数： 1182 最佳路径总距离： 3688
# 迭代次数： 1183 最佳路径总距离： 3688
# 迭代次数： 1184 最佳路径总距离： 3688
# 迭代次数： 1185 最佳路径总距离： 3688
# 迭代次数： 1186 最佳路径总距离： 3688
# 迭代次数： 1187 最佳路径总距离： 3688
# 迭代次数： 1188 最佳路径总距离： 3688
# 迭代次数： 1189 最佳路径总距离： 3688
# 迭代次数： 1190 最佳路径总距离： 3688
# 迭代次数： 1191 最佳路径总距离： 3688
# 迭代次数： 1192 最佳路径总距离： 3688
# 迭代次数： 1193 最佳路径总距离： 3688
# 迭代次数： 1194 最佳路径总距离： 3688
# 迭代次数： 1195 最佳路径总距离： 3688
# 迭代次数： 1196 最佳路径总距离： 3688
# 迭代次数： 1197 最佳路径总距离： 3688
# 迭代次数： 1198 最佳路径总距离： 3688
# 迭代次数： 1199 最佳路径总距离： 3688
# 迭代次数： 1200 最佳路径总距离： 3688
# 迭代次数： 1201 最佳路径总距离： 3688
# 迭代次数： 1202 最佳路径总距离： 3688
# 迭代次数： 1203 最佳路径总距离： 3688
# 迭代次数： 1204 最佳路径总距离： 3688
# 迭代次数： 1205 最佳路径总距离： 3688
# 迭代次数： 1206 最佳路径总距离： 3688
# 迭代次数： 1207 最佳路径总距离： 3688
# 迭代次数： 1208 最佳路径总距离： 3688
# 迭代次数： 1209 最佳路径总距离： 3688
# 迭代次数： 1210 最佳路径总距离： 3688
# 迭代次数： 1211 最佳路径总距离： 3688
# 迭代次数： 1212 最佳路径总距离： 3688
# 迭代次数： 1213 最佳路径总距离： 3688
# 迭代次数： 1214 最佳路径总距离： 3688
# 迭代次数： 1215 最佳路径总距离： 3688
# 迭代次数： 1216 最佳路径总距离： 3688
# 迭代次数： 1217 最佳路径总距离： 3688
# 迭代次数： 1218 最佳路径总距离： 3688
# 迭代次数： 1219 最佳路径总距离： 3688
# 迭代次数： 1220 最佳路径总距离： 3688
# 迭代次数： 1221 最佳路径总距离： 3688
# 迭代次数： 1222 最佳路径总距离： 3688
# 迭代次数： 1223 最佳路径总距离： 3688
# 迭代次数： 1224 最佳路径总距离： 3688
# 迭代次数： 1225 最佳路径总距离： 3688
# 迭代次数： 1226 最佳路径总距离： 3688
# 迭代次数： 1227 最佳路径总距离： 3688
# 迭代次数： 1228 最佳路径总距离： 3688
# 迭代次数： 1229 最佳路径总距离： 3688
# 迭代次数： 1230 最佳路径总距离： 3688
# 迭代次数： 1231 最佳路径总距离： 3688
# 迭代次数： 1232 最佳路径总距离： 3688
# 迭代次数： 1233 最佳路径总距离： 3688
# 迭代次数： 1234 最佳路径总距离： 3688
# 迭代次数： 1235 最佳路径总距离： 3688
# 迭代次数： 1236 最佳路径总距离： 3688
# 迭代次数： 1237 最佳路径总距离： 3688
# 迭代次数： 1238 最佳路径总距离： 3688
# 迭代次数： 1239 最佳路径总距离： 3688
# 迭代次数： 1240 最佳路径总距离： 3688
# 迭代次数： 1241 最佳路径总距离： 3688
# 迭代次数： 1242 最佳路径总距离： 3688
# 迭代次数： 1243 最佳路径总距离： 3688
# 迭代次数： 1244 最佳路径总距离： 3688
# 迭代次数： 1245 最佳路径总距离： 3688
# 迭代次数： 1246 最佳路径总距离： 3688
# 迭代次数： 1247 最佳路径总距离： 3688
# 迭代次数： 1248 最佳路径总距离： 3688
# 迭代次数： 1249 最佳路径总距离： 3688
# 迭代次数： 1250 最佳路径总距离： 3688
# 迭代次数： 1251 最佳路径总距离： 3688
# 迭代次数： 1252 最佳路径总距离： 3688
# 迭代次数： 1253 最佳路径总距离： 3688
# 迭代次数： 1254 最佳路径总距离： 3688
# 迭代次数： 1255 最佳路径总距离： 3688
# 迭代次数： 1256 最佳路径总距离： 3688
# 迭代次数： 1257 最佳路径总距离： 3688
# 迭代次数： 1258 最佳路径总距离： 3688
# 迭代次数： 1259 最佳路径总距离： 3688
# 迭代次数： 1260 最佳路径总距离： 3688
# 迭代次数： 1261 最佳路径总距离： 3688
# 迭代次数： 1262 最佳路径总距离： 3688
# 迭代次数： 1263 最佳路径总距离： 3688
# 迭代次数： 1264 最佳路径总距离： 3688
# 迭代次数： 1265 最佳路径总距离： 3688
# 迭代次数： 1266 最佳路径总距离： 3688
# 迭代次数： 1267 最佳路径总距离： 3688
# 迭代次数： 1268 最佳路径总距离： 3688
# 迭代次数： 1269 最佳路径总距离： 3688
# 迭代次数： 1270 最佳路径总距离： 3688
# 迭代次数： 1271 最佳路径总距离： 3688
# 迭代次数： 1272 最佳路径总距离： 3688
# 迭代次数： 1273 最佳路径总距离： 3688
# 迭代次数： 1274 最佳路径总距离： 3688
# 迭代次数： 1275 最佳路径总距离： 3688
# 迭代次数： 1276 最佳路径总距离： 3688
# 迭代次数： 1277 最佳路径总距离： 3688
# 迭代次数： 1278 最佳路径总距离： 3688
# 迭代次数： 1279 最佳路径总距离： 3688
# 迭代次数： 1280 最佳路径总距离： 3688
# 迭代次数： 1281 最佳路径总距离： 3688
# 迭代次数： 1282 最佳路径总距离： 3688
# 迭代次数： 1283 最佳路径总距离： 3688
# 迭代次数： 1284 最佳路径总距离： 3688
# 迭代次数： 1285 最佳路径总距离： 3688
# 迭代次数： 1286 最佳路径总距离： 3688
# 迭代次数： 1287 最佳路径总距离： 3688
# 迭代次数： 1288 最佳路径总距离： 3688
# 迭代次数： 1289 最佳路径总距离： 3688
# 迭代次数： 1290 最佳路径总距离： 3688
# 迭代次数： 1291 最佳路径总距离： 3688
# 迭代次数： 1292 最佳路径总距离： 3688
# 迭代次数： 1293 最佳路径总距离： 3688
# 迭代次数： 1294 最佳路径总距离： 3688
# 迭代次数： 1295 最佳路径总距离： 3688
# 迭代次数： 1296 最佳路径总距离： 3688
# 迭代次数： 1297 最佳路径总距离： 3688
# 迭代次数： 1298 最佳路径总距离： 3688
# 迭代次数： 1299 最佳路径总距离： 3688
# 迭代次数： 1300 最佳路径总距离： 3688
# 迭代次数： 1301 最佳路径总距离： 3688
# 迭代次数： 1302 最佳路径总距离： 3688
# 迭代次数： 1303 最佳路径总距离： 3688
# 迭代次数： 1304 最佳路径总距离： 3688
# 迭代次数： 1305 最佳路径总距离： 3688
# 迭代次数： 1306 最佳路径总距离： 3688
# 迭代次数： 1307 最佳路径总距离： 3688
# 迭代次数： 1308 最佳路径总距离： 3688
# 迭代次数： 1309 最佳路径总距离： 3688
# 迭代次数： 1310 最佳路径总距离： 3688
# 迭代次数： 1311 最佳路径总距离： 3688
# 迭代次数： 1312 最佳路径总距离： 3688
# 迭代次数： 1313 最佳路径总距离： 3688
# 迭代次数： 1314 最佳路径总距离： 3688
# 迭代次数： 1315 最佳路径总距离： 3688
# 迭代次数： 1316 最佳路径总距离： 3688
# 迭代次数： 1317 最佳路径总距离： 3688
# 迭代次数： 1318 最佳路径总距离： 3688
# 迭代次数： 1319 最佳路径总距离： 3688
# 迭代次数： 1320 最佳路径总距离： 3688
# 迭代次数： 1321 最佳路径总距离： 3688
# 迭代次数： 1322 最佳路径总距离： 3688
# 迭代次数： 1323 最佳路径总距离： 3688
# 迭代次数： 1324 最佳路径总距离： 3688
# 迭代次数： 1325 最佳路径总距离： 3688
# 迭代次数： 1326 最佳路径总距离： 3688
# 迭代次数： 1327 最佳路径总距离： 3688
# 迭代次数： 1328 最佳路径总距离： 3688
# 迭代次数： 1329 最佳路径总距离： 3688
# 迭代次数： 1330 最佳路径总距离： 3688
# 迭代次数： 1331 最佳路径总距离： 3688
# 迭代次数： 1332 最佳路径总距离： 3688
# 迭代次数： 1333 最佳路径总距离： 3688
# 迭代次数： 1334 最佳路径总距离： 3688
# 迭代次数： 1335 最佳路径总距离： 3688
# 迭代次数： 1336 最佳路径总距离： 3688
# 迭代次数： 1337 最佳路径总距离： 3688
# 迭代次数： 1338 最佳路径总距离： 3688
# 迭代次数： 1339 最佳路径总距离： 3688
# 迭代次数： 1340 最佳路径总距离： 3688
# 迭代次数： 1341 最佳路径总距离： 3688
# 迭代次数： 1342 最佳路径总距离： 3688
# 迭代次数： 1343 最佳路径总距离： 3688
# 迭代次数： 1344 最佳路径总距离： 3688
# 迭代次数： 1345 最佳路径总距离： 3688
# 迭代次数： 1346 最佳路径总距离： 3688
# 迭代次数： 1347 最佳路径总距离： 3688
# 迭代次数： 1348 最佳路径总距离： 3688
# 迭代次数： 1349 最佳路径总距离： 3688
# 迭代次数： 1350 最佳路径总距离： 3688
# 迭代次数： 1351 最佳路径总距离： 3688
# 迭代次数： 1352 最佳路径总距离： 3688
# 迭代次数： 1353 最佳路径总距离： 3688
# 迭代次数： 1354 最佳路径总距离： 3688
# 迭代次数： 1355 最佳路径总距离： 3688
# 迭代次数： 1356 最佳路径总距离： 3688
# 迭代次数： 1357 最佳路径总距离： 3688
# 迭代次数： 1358 最佳路径总距离： 3688
# 迭代次数： 1359 最佳路径总距离： 3688
# 迭代次数： 1360 最佳路径总距离： 3688
# 迭代次数： 1361 最佳路径总距离： 3688
# 迭代次数： 1362 最佳路径总距离： 3688
# 迭代次数： 1363 最佳路径总距离： 3688
# 迭代次数： 1364 最佳路径总距离： 3688
# 迭代次数： 1365 最佳路径总距离： 3688
# 迭代次数： 1366 最佳路径总距离： 3688
# 迭代次数： 1367 最佳路径总距离： 3688
# 迭代次数： 1368 最佳路径总距离： 3688
# 迭代次数： 1369 最佳路径总距离： 3688
# 迭代次数： 1370 最佳路径总距离： 3688
# 迭代次数： 1371 最佳路径总距离： 3688
# 迭代次数： 1372 最佳路径总距离： 3688
# 迭代次数： 1373 最佳路径总距离： 3688
# 迭代次数： 1374 最佳路径总距离： 3688
# 迭代次数： 1375 最佳路径总距离： 3688
# 迭代次数： 1376 最佳路径总距离： 3688
# 迭代次数： 1377 最佳路径总距离： 3688
# 迭代次数： 1378 最佳路径总距离： 3688
# 迭代次数： 1379 最佳路径总距离： 3688
# 迭代次数： 1380 最佳路径总距离： 3688
# 迭代次数： 1381 最佳路径总距离： 3688
# 迭代次数： 1382 最佳路径总距离： 3688
# 迭代次数： 1383 最佳路径总距离： 3688
# 迭代次数： 1384 最佳路径总距离： 3688
# 迭代次数： 1385 最佳路径总距离： 3688
# 迭代次数： 1386 最佳路径总距离： 3688
# 迭代次数： 1387 最佳路径总距离： 3688
# 迭代次数： 1388 最佳路径总距离： 3688
# 迭代次数： 1389 最佳路径总距离： 3688
# 迭代次数： 1390 最佳路径总距离： 3688
# 迭代次数： 1391 最佳路径总距离： 3688
# 迭代次数： 1392 最佳路径总距离： 3688
# 迭代次数： 1393 最佳路径总距离： 3688
# 迭代次数： 1394 最佳路径总距离： 3688
# 迭代次数： 1395 最佳路径总距离： 3688
# 迭代次数： 1396 最佳路径总距离： 3688
# 迭代次数： 1397 最佳路径总距离： 3688
# 迭代次数： 1398 最佳路径总距离： 3688
# 迭代次数： 1399 最佳路径总距离： 3688
# 迭代次数： 1400 最佳路径总距离： 3688
# 迭代次数： 1401 最佳路径总距离： 3688
# 迭代次数： 1402 最佳路径总距离： 3688
# 迭代次数： 1403 最佳路径总距离： 3688
# 迭代次数： 1404 最佳路径总距离： 3688
# 迭代次数： 1405 最佳路径总距离： 3688
# 迭代次数： 1406 最佳路径总距离： 3688
# 迭代次数： 1407 最佳路径总距离： 3688
# 迭代次数： 1408 最佳路径总距离： 3688
# 迭代次数： 1409 最佳路径总距离： 3688
# 迭代次数： 1410 最佳路径总距离： 3688
# 迭代次数： 1411 最佳路径总距离： 3688
# 迭代次数： 1412 最佳路径总距离： 3688
# 迭代次数： 1413 最佳路径总距离： 3688
# 迭代次数： 1414 最佳路径总距离： 3688
# 迭代次数： 1415 最佳路径总距离： 3688
# 迭代次数： 1416 最佳路径总距离： 3688
# 迭代次数： 1417 最佳路径总距离： 3688
# 迭代次数： 1418 最佳路径总距离： 3688
# 迭代次数： 1419 最佳路径总距离： 3688
# 迭代次数： 1420 最佳路径总距离： 3688
# 迭代次数： 1421 最佳路径总距离： 3688
# 迭代次数： 1422 最佳路径总距离： 3688
# 迭代次数： 1423 最佳路径总距离： 3688
# 迭代次数： 1424 最佳路径总距离： 3688
# 迭代次数： 1425 最佳路径总距离： 3688
# 迭代次数： 1426 最佳路径总距离： 3688
# 迭代次数： 1427 最佳路径总距离： 3688
# 迭代次数： 1428 最佳路径总距离： 3688
# 迭代次数： 1429 最佳路径总距离： 3688
# 迭代次数： 1430 最佳路径总距离： 3688
# 迭代次数： 1431 最佳路径总距离： 3688
# 迭代次数： 1432 最佳路径总距离： 3688
# 迭代次数： 1433 最佳路径总距离： 3688
# 迭代次数： 1434 最佳路径总距离： 3688
# 迭代次数： 1435 最佳路径总距离： 3688
# 迭代次数： 1436 最佳路径总距离： 3688
# 迭代次数： 1437 最佳路径总距离： 3688
# 迭代次数： 1438 最佳路径总距离： 3688
# 迭代次数： 1439 最佳路径总距离： 3688
# 迭代次数： 1440 最佳路径总距离： 3688
# 迭代次数： 1441 最佳路径总距离： 3688
# 迭代次数： 1442 最佳路径总距离： 3688
# 迭代次数： 1443 最佳路径总距离： 3688
# 迭代次数： 1444 最佳路径总距离： 3688
# 迭代次数： 1445 最佳路径总距离： 3688
# 迭代次数： 1446 最佳路径总距离： 3688
# 迭代次数： 1447 最佳路径总距离： 3688
# 迭代次数： 1448 最佳路径总距离： 3688
# 迭代次数： 1449 最佳路径总距离： 3688
# 迭代次数： 1450 最佳路径总距离： 3688
# 迭代次数： 1451 最佳路径总距离： 3688
# 迭代次数： 1452 最佳路径总距离： 3688
# 迭代次数： 1453 最佳路径总距离： 3688
# 迭代次数： 1454 最佳路径总距离： 3688
# 迭代次数： 1455 最佳路径总距离： 3688
# 迭代次数： 1456 最佳路径总距离： 3688
# 迭代次数： 1457 最佳路径总距离： 3688
# 迭代次数： 1458 最佳路径总距离： 3688
# 迭代次数： 1459 最佳路径总距离： 3688
# 迭代次数： 1460 最佳路径总距离： 3688
# 迭代次数： 1461 最佳路径总距离： 3688
# 迭代次数： 1462 最佳路径总距离： 3688
# 迭代次数： 1463 最佳路径总距离： 3688
# 迭代次数： 1464 最佳路径总距离： 3688
# 迭代次数： 1465 最佳路径总距离： 3688
# 迭代次数： 1466 最佳路径总距离： 3688
# 迭代次数： 1467 最佳路径总距离： 3688
# 迭代次数： 1468 最佳路径总距离： 3688
# 迭代次数： 1469 最佳路径总距离： 3688
# 迭代次数： 1470 最佳路径总距离： 3688
# 迭代次数： 1471 最佳路径总距离： 3688
# 迭代次数： 1472 最佳路径总距离： 3688
# 迭代次数： 1473 最佳路径总距离： 3688
# 迭代次数： 1474 最佳路径总距离： 3688
# 迭代次数： 1475 最佳路径总距离： 3688
# 迭代次数： 1476 最佳路径总距离： 3688
# 迭代次数： 1477 最佳路径总距离： 3688
# 迭代次数： 1478 最佳路径总距离： 3688
# 迭代次数： 1479 最佳路径总距离： 3688
# 迭代次数： 1480 最佳路径总距离： 3688
# 迭代次数： 1481 最佳路径总距离： 3688
# 迭代次数： 1482 最佳路径总距离： 3688
# 迭代次数： 1483 最佳路径总距离： 3688
# 迭代次数： 1484 最佳路径总距离： 3688
# 迭代次数： 1485 最佳路径总距离： 3688
# 迭代次数： 1486 最佳路径总距离： 3688
# 迭代次数： 1487 最佳路径总距离： 3688
# 迭代次数： 1488 最佳路径总距离： 3688
# 迭代次数： 1489 最佳路径总距离： 3688
# 迭代次数： 1490 最佳路径总距离： 3688
# 迭代次数： 1491 最佳路径总距离： 3688
# 迭代次数： 1492 最佳路径总距离： 3688
# 迭代次数： 1493 最佳路径总距离： 3688
# 迭代次数： 1494 最佳路径总距离： 3688
# 迭代次数： 1495 最佳路径总距离： 3688
# 迭代次数： 1496 最佳路径总距离： 3688
# 迭代次数： 1497 最佳路径总距离： 3688
# 迭代次数： 1498 最佳路径总距离： 3688
# 迭代次数： 1499 最佳路径总距离： 3688
# 迭代次数： 1500 最佳路径总距离： 3688
# 迭代次数： 1501 最佳路径总距离： 3688
# 迭代次数： 1502 最佳路径总距离： 3688
# 迭代次数： 1503 最佳路径总距离： 3688
# 迭代次数： 1504 最佳路径总距离： 3688
# 迭代次数： 1505 最佳路径总距离： 3688
# 迭代次数： 1506 最佳路径总距离： 3688
# 迭代次数： 1507 最佳路径总距离： 3688
# 迭代次数： 1508 最佳路径总距离： 3688
# 迭代次数： 1509 最佳路径总距离： 3688
# 迭代次数： 1510 最佳路径总距离： 3688
# 迭代次数： 1511 最佳路径总距离： 3688
# 迭代次数： 1512 最佳路径总距离： 3688
# 迭代次数： 1513 最佳路径总距离： 3688
# 迭代次数： 1514 最佳路径总距离： 3688
# 迭代次数： 1515 最佳路径总距离： 3688
# 迭代次数： 1516 最佳路径总距离： 3688
# 迭代次数： 1517 最佳路径总距离： 3688
# 迭代次数： 1518 最佳路径总距离： 3688
# 迭代次数： 1519 最佳路径总距离： 3688
# 迭代次数： 1520 最佳路径总距离： 3688
# 迭代次数： 1521 最佳路径总距离： 3688
# 迭代次数： 1522 最佳路径总距离： 3688
# 迭代次数： 1523 最佳路径总距离： 3688
# 迭代次数： 1524 最佳路径总距离： 3688
# 迭代次数： 1525 最佳路径总距离： 3688
# 迭代次数： 1526 最佳路径总距离： 3688
# 迭代次数： 1527 最佳路径总距离： 3688
# 迭代次数： 1528 最佳路径总距离： 3688
# 迭代次数： 1529 最佳路径总距离： 3688
# 迭代次数： 1530 最佳路径总距离： 3688
# 迭代次数： 1531 最佳路径总距离： 3688
# 迭代次数： 1532 最佳路径总距离： 3688
# 迭代次数： 1533 最佳路径总距离： 3688
# 迭代次数： 1534 最佳路径总距离： 3688
# 迭代次数： 1535 最佳路径总距离： 3688
# 迭代次数： 1536 最佳路径总距离： 3688
# 迭代次数： 1537 最佳路径总距离： 3688
# 迭代次数： 1538 最佳路径总距离： 3688
# 迭代次数： 1539 最佳路径总距离： 3688
# 迭代次数： 1540 最佳路径总距离： 3688
# 迭代次数： 1541 最佳路径总距离： 3688
# 迭代次数： 1542 最佳路径总距离： 3688
# 迭代次数： 1543 最佳路径总距离： 3688
# 迭代次数： 1544 最佳路径总距离： 3688
# 迭代次数： 1545 最佳路径总距离： 3688
# 迭代次数： 1546 最佳路径总距离： 3688
# 迭代次数： 1547 最佳路径总距离： 3688
# 迭代次数： 1548 最佳路径总距离： 3688
# 迭代次数： 1549 最佳路径总距离： 3688
# 迭代次数： 1550 最佳路径总距离： 3688
# 迭代次数： 1551 最佳路径总距离： 3688
# 迭代次数： 1552 最佳路径总距离： 3688
# 迭代次数： 1553 最佳路径总距离： 3688
# 迭代次数： 1554 最佳路径总距离： 3688
# 迭代次数： 1555 最佳路径总距离： 3688
# 迭代次数： 1556 最佳路径总距离： 3688
# 迭代次数： 1557 最佳路径总距离： 3688
# 迭代次数： 1558 最佳路径总距离： 3688
# 迭代次数： 1559 最佳路径总距离： 3688
# 迭代次数： 1560 最佳路径总距离： 3688
# 迭代次数： 1561 最佳路径总距离： 3688
# 迭代次数： 1562 最佳路径总距离： 3688
# 迭代次数： 1563 最佳路径总距离： 3688
# 迭代次数： 1564 最佳路径总距离： 3688
# 迭代次数： 1565 最佳路径总距离： 3688
# 迭代次数： 1566 最佳路径总距离： 3688
# 迭代次数： 1567 最佳路径总距离： 3688
# 迭代次数： 1568 最佳路径总距离： 3688
# 迭代次数： 1569 最佳路径总距离： 3688
# 迭代次数： 1570 最佳路径总距离： 3688
# 迭代次数： 1571 最佳路径总距离： 3688
# 迭代次数： 1572 最佳路径总距离： 3688
# 迭代次数： 1573 最佳路径总距离： 3688
# 迭代次数： 1574 最佳路径总距离： 3688
# 迭代次数： 1575 最佳路径总距离： 3688
# 迭代次数： 1576 最佳路径总距离： 3688
# 迭代次数： 1577 最佳路径总距离： 3688
# 迭代次数： 1578 最佳路径总距离： 3688
# 迭代次数： 1579 最佳路径总距离： 3688
# 迭代次数： 1580 最佳路径总距离： 3688
# 迭代次数： 1581 最佳路径总距离： 3688
# 迭代次数： 1582 最佳路径总距离： 3688
# 迭代次数： 1583 最佳路径总距离： 3688
# 迭代次数： 1584 最佳路径总距离： 3688
# 迭代次数： 1585 最佳路径总距离： 3688
# 迭代次数： 1586 最佳路径总距离： 3688
# 迭代次数： 1587 最佳路径总距离： 3688
# 迭代次数： 1588 最佳路径总距离： 3688
# 迭代次数： 1589 最佳路径总距离： 3688
# 迭代次数： 1590 最佳路径总距离： 3688
# 迭代次数： 1591 最佳路径总距离： 3688
# 迭代次数： 1592 最佳路径总距离： 3688
# 迭代次数： 1593 最佳路径总距离： 3688
# 迭代次数： 1594 最佳路径总距离： 3688
# 迭代次数： 1595 最佳路径总距离： 3688
# 迭代次数： 1596 最佳路径总距离： 3688
# 迭代次数： 1597 最佳路径总距离： 3688
# 迭代次数： 1598 最佳路径总距离： 3688
# 迭代次数： 1599 最佳路径总距离： 3688
# 迭代次数： 1600 最佳路径总距离： 3688
# 迭代次数： 1601 最佳路径总距离： 3688
# 迭代次数： 1602 最佳路径总距离： 3688
# 迭代次数： 1603 最佳路径总距离： 3688
# 迭代次数： 1604 最佳路径总距离： 3688
# 迭代次数： 1605 最佳路径总距离： 3688
# 迭代次数： 1606 最佳路径总距离： 3688
# 迭代次数： 1607 最佳路径总距离： 3688
# 迭代次数： 1608 最佳路径总距离： 3688
# 迭代次数： 1609 最佳路径总距离： 3688
# 迭代次数： 1610 最佳路径总距离： 3688
# 迭代次数： 1611 最佳路径总距离： 3688
# 迭代次数： 1612 最佳路径总距离： 3688
# 迭代次数： 1613 最佳路径总距离： 3688
# 迭代次数： 1614 最佳路径总距离： 3688
# 迭代次数： 1615 最佳路径总距离： 3688
# 迭代次数： 1616 最佳路径总距离： 3688
# 迭代次数： 1617 最佳路径总距离： 3688
# 迭代次数： 1618 最佳路径总距离： 3688
# 迭代次数： 1619 最佳路径总距离： 3688
# 迭代次数： 1620 最佳路径总距离： 3688
# 迭代次数： 1621 最佳路径总距离： 3688
# 迭代次数： 1622 最佳路径总距离： 3688
# 迭代次数： 1623 最佳路径总距离： 3688
# 迭代次数： 1624 最佳路径总距离： 3688
# 迭代次数： 1625 最佳路径总距离： 3688
# 迭代次数： 1626 最佳路径总距离： 3688
# 迭代次数： 1627 最佳路径总距离： 3688
# 迭代次数： 1628 最佳路径总距离： 3688
# 迭代次数： 1629 最佳路径总距离： 3688
# 迭代次数： 1630 最佳路径总距离： 3688
# 迭代次数： 1631 最佳路径总距离： 3688
# 迭代次数： 1632 最佳路径总距离： 3688
# 迭代次数： 1633 最佳路径总距离： 3688
# 迭代次数： 1634 最佳路径总距离： 3688
# 迭代次数： 1635 最佳路径总距离： 3688
# 迭代次数： 1636 最佳路径总距离： 3688
# 迭代次数： 1637 最佳路径总距离： 3688
# 迭代次数： 1638 最佳路径总距离： 3688
# 迭代次数： 1639 最佳路径总距离： 3688
# 迭代次数： 1640 最佳路径总距离： 3688
# 迭代次数： 1641 最佳路径总距离： 3688
# 迭代次数： 1642 最佳路径总距离： 3688
# 迭代次数： 1643 最佳路径总距离： 3688
# 迭代次数： 1644 最佳路径总距离： 3688
# 迭代次数： 1645 最佳路径总距离： 3688
# 迭代次数： 1646 最佳路径总距离： 3688
# 迭代次数： 1647 最佳路径总距离： 3688
# 迭代次数： 1648 最佳路径总距离： 3688
# 迭代次数： 1649 最佳路径总距离： 3688
# 迭代次数： 1650 最佳路径总距离： 3688
# 迭代次数： 1651 最佳路径总距离： 3688
# 迭代次数： 1652 最佳路径总距离： 3688
# 迭代次数： 1653 最佳路径总距离： 3688
# 迭代次数： 1654 最佳路径总距离： 3688
# 迭代次数： 1655 最佳路径总距离： 3688
# 迭代次数： 1656 最佳路径总距离： 3688
# 迭代次数： 1657 最佳路径总距离： 3688
# 迭代次数： 1658 最佳路径总距离： 3688
# 迭代次数： 1659 最佳路径总距离： 3688
# 迭代次数： 1660 最佳路径总距离： 3688
# 迭代次数： 1661 最佳路径总距离： 3688
# 迭代次数： 1662 最佳路径总距离： 3688
# 迭代次数： 1663 最佳路径总距离： 3688
# 迭代次数： 1664 最佳路径总距离： 3688
# 迭代次数： 1665 最佳路径总距离： 3688
# 迭代次数： 1666 最佳路径总距离： 3688
# 迭代次数： 1667 最佳路径总距离： 3688
# 迭代次数： 1668 最佳路径总距离： 3688
# 迭代次数： 1669 最佳路径总距离： 3688
# 迭代次数： 1670 最佳路径总距离： 3688
# 迭代次数： 1671 最佳路径总距离： 3688
# 迭代次数： 1672 最佳路径总距离： 3688
# 迭代次数： 1673 最佳路径总距离： 3688
# 迭代次数： 1674 最佳路径总距离： 3688
# 迭代次数： 1675 最佳路径总距离： 3688
# 迭代次数： 1676 最佳路径总距离： 3688
# 迭代次数： 1677 最佳路径总距离： 3688
# 迭代次数： 1678 最佳路径总距离： 3688
# 迭代次数： 1679 最佳路径总距离： 3688
# 迭代次数： 1680 最佳路径总距离： 3688
# 迭代次数： 1681 最佳路径总距离： 3688
# 迭代次数： 1682 最佳路径总距离： 3688
# 迭代次数： 1683 最佳路径总距离： 3688
# 迭代次数： 1684 最佳路径总距离： 3688
# 迭代次数： 1685 最佳路径总距离： 3688
# 迭代次数： 1686 最佳路径总距离： 3688
# 迭代次数： 1687 最佳路径总距离： 3688
# 迭代次数： 1688 最佳路径总距离： 3688
# 迭代次数： 1689 最佳路径总距离： 3688
# 迭代次数： 1690 最佳路径总距离： 3688
# 迭代次数： 1691 最佳路径总距离： 3688
# 迭代次数： 1692 最佳路径总距离： 3688
# 迭代次数： 1693 最佳路径总距离： 3688
# 迭代次数： 1694 最佳路径总距离： 3688
# 迭代次数： 1695 最佳路径总距离： 3688
# 迭代次数： 1696 最佳路径总距离： 3688
# 迭代次数： 1697 最佳路径总距离： 3688
# 迭代次数： 1698 最佳路径总距离： 3688
# 迭代次数： 1699 最佳路径总距离： 3688
# 迭代次数： 1700 最佳路径总距离： 3688
# 迭代次数： 1701 最佳路径总距离： 3688
# 迭代次数： 1702 最佳路径总距离： 3688
# 迭代次数： 1703 最佳路径总距离： 3688
# 迭代次数： 1704 最佳路径总距离： 3688
# 迭代次数： 1705 最佳路径总距离： 3688
# 迭代次数： 1706 最佳路径总距离： 3688
# 迭代次数： 1707 最佳路径总距离： 3688
# 迭代次数： 1708 最佳路径总距离： 3688
# 迭代次数： 1709 最佳路径总距离： 3688
# 迭代次数： 1710 最佳路径总距离： 3688
# 迭代次数： 1711 最佳路径总距离： 3688
# 迭代次数： 1712 最佳路径总距离： 3688
# 迭代次数： 1713 最佳路径总距离： 3688
# 迭代次数： 1714 最佳路径总距离： 3688
# 迭代次数： 1715 最佳路径总距离： 3688
# 迭代次数： 1716 最佳路径总距离： 3688
# 迭代次数： 1717 最佳路径总距离： 3688
# 迭代次数： 1718 最佳路径总距离： 3688
# 迭代次数： 1719 最佳路径总距离： 3688
# 迭代次数： 1720 最佳路径总距离： 3688
# 迭代次数： 1721 最佳路径总距离： 3688
# 迭代次数： 1722 最佳路径总距离： 3688
# 迭代次数： 1723 最佳路径总距离： 3688
# 迭代次数： 1724 最佳路径总距离： 3688
# 迭代次数： 1725 最佳路径总距离： 3688
# 迭代次数： 1726 最佳路径总距离： 3688
# 迭代次数： 1727 最佳路径总距离： 3688
# 迭代次数： 1728 最佳路径总距离： 3688
# 迭代次数： 1729 最佳路径总距离： 3688
# 迭代次数： 1730 最佳路径总距离： 3688
# 迭代次数： 1731 最佳路径总距离： 3688
# 迭代次数： 1732 最佳路径总距离： 3688
# 迭代次数： 1733 最佳路径总距离： 3688
# 迭代次数： 1734 最佳路径总距离： 3688
# 迭代次数： 1735 最佳路径总距离： 3688
# 迭代次数： 1736 最佳路径总距离： 3688
# 迭代次数： 1737 最佳路径总距离： 3688
# 迭代次数： 1738 最佳路径总距离： 3688
# 迭代次数： 1739 最佳路径总距离： 3688
# 迭代次数： 1740 最佳路径总距离： 3688
# 迭代次数： 1741 最佳路径总距离： 3688
# 迭代次数： 1742 最佳路径总距离： 3688
# 迭代次数： 1743 最佳路径总距离： 3688
# 迭代次数： 1744 最佳路径总距离： 3688
# 迭代次数： 1745 最佳路径总距离： 3688
# 迭代次数： 1746 最佳路径总距离： 3688
# 迭代次数： 1747 最佳路径总距离： 3688
# 迭代次数： 1748 最佳路径总距离： 3688
# 迭代次数： 1749 最佳路径总距离： 3688
# 迭代次数： 1750 最佳路径总距离： 3688
# 迭代次数： 1751 最佳路径总距离： 3688
# 迭代次数： 1752 最佳路径总距离： 3688
# 迭代次数： 1753 最佳路径总距离： 3688
# 迭代次数： 1754 最佳路径总距离： 3687
# 迭代次数： 1755 最佳路径总距离： 3687
# 迭代次数： 1756 最佳路径总距离： 3687
# 迭代次数： 1757 最佳路径总距离： 3687
# 迭代次数： 1758 最佳路径总距离： 3687
# 迭代次数： 1759 最佳路径总距离： 3687
# 迭代次数： 1760 最佳路径总距离： 3687
# 迭代次数： 1761 最佳路径总距离： 3687
# 迭代次数： 1762 最佳路径总距离： 3687
# 迭代次数： 1763 最佳路径总距离： 3687
# 迭代次数： 1764 最佳路径总距离： 3687
# 迭代次数： 1765 最佳路径总距离： 3687
# 迭代次数： 1766 最佳路径总距离： 3687
# 迭代次数： 1767 最佳路径总距离： 3687
# 迭代次数： 1768 最佳路径总距离： 3687
# 迭代次数： 1769 最佳路径总距离： 3687
# 迭代次数： 1770 最佳路径总距离： 3687
# 迭代次数： 1771 最佳路径总距离： 3687
# 迭代次数： 1772 最佳路径总距离： 3687
# 迭代次数： 1773 最佳路径总距离： 3687
# 迭代次数： 1774 最佳路径总距离： 3687
# 迭代次数： 1775 最佳路径总距离： 3687
# 迭代次数： 1776 最佳路径总距离： 3687
# 迭代次数： 1777 最佳路径总距离： 3687
# 迭代次数： 1778 最佳路径总距离： 3687
# 迭代次数： 1779 最佳路径总距离： 3687
# 迭代次数： 1780 最佳路径总距离： 3687
# 迭代次数： 1781 最佳路径总距离： 3687
# 迭代次数： 1782 最佳路径总距离： 3687
# 迭代次数： 1783 最佳路径总距离： 3687
# 迭代次数： 1784 最佳路径总距离： 3687
# 迭代次数： 1785 最佳路径总距离： 3687
# 迭代次数： 1786 最佳路径总距离： 3687
# 迭代次数： 1787 最佳路径总距离： 3687
# 迭代次数： 1788 最佳路径总距离： 3687
# 迭代次数： 1789 最佳路径总距离： 3687
# 迭代次数： 1790 最佳路径总距离： 3687
# 迭代次数： 1791 最佳路径总距离： 3687
# 迭代次数： 1792 最佳路径总距离： 3687
# 迭代次数： 1793 最佳路径总距离： 3687
# 迭代次数： 1794 最佳路径总距离： 3687
# 迭代次数： 1795 最佳路径总距离： 3687
# 迭代次数： 1796 最佳路径总距离： 3687
# 迭代次数： 1797 最佳路径总距离： 3687
# 迭代次数： 1798 最佳路径总距离： 3687
# 迭代次数： 1799 最佳路径总距离： 3687
# 迭代次数： 1800 最佳路径总距离： 3687
# 迭代次数： 1801 最佳路径总距离： 3687
# 迭代次数： 1802 最佳路径总距离： 3687
# 迭代次数： 1803 最佳路径总距离： 3687
# 迭代次数： 1804 最佳路径总距离： 3687
# 迭代次数： 1805 最佳路径总距离： 3687
# 迭代次数： 1806 最佳路径总距离： 3687
# 迭代次数： 1807 最佳路径总距离： 3687
# 迭代次数： 1808 最佳路径总距离： 3687
# 迭代次数： 1809 最佳路径总距离： 3687
# 迭代次数： 1810 最佳路径总距离： 3687
# 迭代次数： 1811 最佳路径总距离： 3687
# 迭代次数： 1812 最佳路径总距离： 3687
# 迭代次数： 1813 最佳路径总距离： 3687
# 迭代次数： 1814 最佳路径总距离： 3687
# 迭代次数： 1815 最佳路径总距离： 3687
# 迭代次数： 1816 最佳路径总距离： 3687
# 迭代次数： 1817 最佳路径总距离： 3687
# 迭代次数： 1818 最佳路径总距离： 3687
# 迭代次数： 1819 最佳路径总距离： 3687
# 迭代次数： 1820 最佳路径总距离： 3687
# 迭代次数： 1821 最佳路径总距离： 3687
# 迭代次数： 1822 最佳路径总距离： 3687
# 迭代次数： 1823 最佳路径总距离： 3687
# 迭代次数： 1824 最佳路径总距离： 3687
# 迭代次数： 1825 最佳路径总距离： 3687
# 迭代次数： 1826 最佳路径总距离： 3687
# 迭代次数： 1827 最佳路径总距离： 3687
# 迭代次数： 1828 最佳路径总距离： 3687
# 迭代次数： 1829 最佳路径总距离： 3687
# 迭代次数： 1830 最佳路径总距离： 3687
# 迭代次数： 1831 最佳路径总距离： 3687
# 迭代次数： 1832 最佳路径总距离： 3687
# 迭代次数： 1833 最佳路径总距离： 3687
# 迭代次数： 1834 最佳路径总距离： 3687
# 迭代次数： 1835 最佳路径总距离： 3687
# 迭代次数： 1836 最佳路径总距离： 3687
# 迭代次数： 1837 最佳路径总距离： 3687
# 迭代次数： 1838 最佳路径总距离： 3687
# 迭代次数： 1839 最佳路径总距离： 3687
# 迭代次数： 1840 最佳路径总距离： 3687
# 迭代次数： 1841 最佳路径总距离： 3687
# 迭代次数： 1842 最佳路径总距离： 3687
# 迭代次数： 1843 最佳路径总距离： 3687
# 迭代次数： 1844 最佳路径总距离： 3687
# 迭代次数： 1845 最佳路径总距离： 3687
# 迭代次数： 1846 最佳路径总距离： 3687
# 迭代次数： 1847 最佳路径总距离： 3687
# 迭代次数： 1848 最佳路径总距离： 3687
# 迭代次数： 1849 最佳路径总距离： 3687
# 迭代次数： 1850 最佳路径总距离： 3687
# 迭代次数： 1851 最佳路径总距离： 3687
# 迭代次数： 1852 最佳路径总距离： 3687
# 迭代次数： 1853 最佳路径总距离： 3687
# 迭代次数： 1854 最佳路径总距离： 3687
# 迭代次数： 1855 最佳路径总距离： 3687
# 迭代次数： 1856 最佳路径总距离： 3687
# 迭代次数： 1857 最佳路径总距离： 3687
# 迭代次数： 1858 最佳路径总距离： 3687
# 迭代次数： 1859 最佳路径总距离： 3687
# 迭代次数： 1860 最佳路径总距离： 3687
# 迭代次数： 1861 最佳路径总距离： 3687
# 迭代次数： 1862 最佳路径总距离： 3687
# 迭代次数： 1863 最佳路径总距离： 3687
# 迭代次数： 1864 最佳路径总距离： 3687
# 迭代次数： 1865 最佳路径总距离： 3687
# 迭代次数： 1866 最佳路径总距离： 3687
# 迭代次数： 1867 最佳路径总距离： 3687
# 迭代次数： 1868 最佳路径总距离： 3687
# 迭代次数： 1869 最佳路径总距离： 3687
# 迭代次数： 1870 最佳路径总距离： 3687
# 迭代次数： 1871 最佳路径总距离： 3687
# 迭代次数： 1872 最佳路径总距离： 3687
# 迭代次数： 1873 最佳路径总距离： 3687
# 迭代次数： 1874 最佳路径总距离： 3687
# 迭代次数： 1875 最佳路径总距离： 3687
# 迭代次数： 1876 最佳路径总距离： 3687
# 迭代次数： 1877 最佳路径总距离： 3687
# 迭代次数： 1878 最佳路径总距离： 3687
# 迭代次数： 1879 最佳路径总距离： 3687
# 迭代次数： 1880 最佳路径总距离： 3687
# 迭代次数： 1881 最佳路径总距离： 3687
# 迭代次数： 1882 最佳路径总距离： 3687
# 迭代次数： 1883 最佳路径总距离： 3687
# 迭代次数： 1884 最佳路径总距离： 3687
# 迭代次数： 1885 最佳路径总距离： 3687
# 迭代次数： 1886 最佳路径总距离： 3687
# 迭代次数： 1887 最佳路径总距离： 3687
# 迭代次数： 1888 最佳路径总距离： 3687
# 迭代次数： 1889 最佳路径总距离： 3687
# 迭代次数： 1890 最佳路径总距离： 3687
# 迭代次数： 1891 最佳路径总距离： 3687
# 迭代次数： 1892 最佳路径总距离： 3687
# 迭代次数： 1893 最佳路径总距离： 3687
# 迭代次数： 1894 最佳路径总距离： 3687
# 迭代次数： 1895 最佳路径总距离： 3687
# 迭代次数： 1896 最佳路径总距离： 3687
# 迭代次数： 1897 最佳路径总距离： 3687
# 迭代次数： 1898 最佳路径总距离： 3687
# 迭代次数： 1899 最佳路径总距离： 3687
# 迭代次数： 1900 最佳路径总距离： 3687
# 迭代次数： 1901 最佳路径总距离： 3687
# 迭代次数： 1902 最佳路径总距离： 3687
# 迭代次数： 1903 最佳路径总距离： 3687
# 迭代次数： 1904 最佳路径总距离： 3687
# 迭代次数： 1905 最佳路径总距离： 3687
# 迭代次数： 1906 最佳路径总距离： 3687
# 迭代次数： 1907 最佳路径总距离： 3687
# 迭代次数： 1908 最佳路径总距离： 3687
# 迭代次数： 1909 最佳路径总距离： 3687
# 迭代次数： 1910 最佳路径总距离： 3687
# 迭代次数： 1911 最佳路径总距离： 3687
# 迭代次数： 1912 最佳路径总距离： 3687
# 迭代次数： 1913 最佳路径总距离： 3687
# 迭代次数： 1914 最佳路径总距离： 3687
# 迭代次数： 1915 最佳路径总距离： 3687
# 迭代次数： 1916 最佳路径总距离： 3687
# 迭代次数： 1917 最佳路径总距离： 3687
# 迭代次数： 1918 最佳路径总距离： 3687
# 迭代次数： 1919 最佳路径总距离： 3687
# 迭代次数： 1920 最佳路径总距离： 3687
# 迭代次数： 1921 最佳路径总距离： 3687
# 迭代次数： 1922 最佳路径总距离： 3687
# 迭代次数： 1923 最佳路径总距离： 3687
# 迭代次数： 1924 最佳路径总距离： 3687
# 迭代次数： 1925 最佳路径总距离： 3687
# 迭代次数： 1926 最佳路径总距离： 3687
# 迭代次数： 1927 最佳路径总距离： 3687
# 迭代次数： 1928 最佳路径总距离： 3687
# 迭代次数： 1929 最佳路径总距离： 3687
# 迭代次数： 1930 最佳路径总距离： 3687
# 迭代次数： 1931 最佳路径总距离： 3687
# 迭代次数： 1932 最佳路径总距离： 3687
# 迭代次数： 1933 最佳路径总距离： 3687
# 迭代次数： 1934 最佳路径总距离： 3687
# 迭代次数： 1935 最佳路径总距离： 3687
# 迭代次数： 1936 最佳路径总距离： 3687
# 迭代次数： 1937 最佳路径总距离： 3687
# 迭代次数： 1938 最佳路径总距离： 3687
# 迭代次数： 1939 最佳路径总距离： 3687
# 迭代次数： 1940 最佳路径总距离： 3687
# 迭代次数： 1941 最佳路径总距离： 3687
# 迭代次数： 1942 最佳路径总距离： 3687
# 迭代次数： 1943 最佳路径总距离： 3687
# 迭代次数： 1944 最佳路径总距离： 3687
# 迭代次数： 1945 最佳路径总距离： 3687
# 迭代次数： 1946 最佳路径总距离： 3687
# 迭代次数： 1947 最佳路径总距离： 3687
# 迭代次数： 1948 最佳路径总距离： 3687
# 迭代次数： 1949 最佳路径总距离： 3687
# 迭代次数： 1950 最佳路径总距离： 3687
# 迭代次数： 1951 最佳路径总距离： 3687
# 迭代次数： 1952 最佳路径总距离： 3687
# 迭代次数： 1953 最佳路径总距离： 3687
# 迭代次数： 1954 最佳路径总距离： 3687
# 迭代次数： 1955 最佳路径总距离： 3687
# 迭代次数： 1956 最佳路径总距离： 3687
# 迭代次数： 1957 最佳路径总距离： 3687
# 迭代次数： 1958 最佳路径总距离： 3687
# 迭代次数： 1959 最佳路径总距离： 3687
# 迭代次数： 1960 最佳路径总距离： 3687
# 迭代次数： 1961 最佳路径总距离： 3687
# 迭代次数： 1962 最佳路径总距离： 3687
# 迭代次数： 1963 最佳路径总距离： 3687
# 迭代次数： 1964 最佳路径总距离： 3687
# ...
# 迭代次数： 6774 最佳路径总距离： 3687
# 迭代次数： 6775 最佳路径总距离： 3687
# 迭代次数： 6776 最佳路径总距离： 3687
# 迭代次数： 6777 最佳路径总距离： 3687
# 迭代次数： 6778 最佳路径总距离： 3687
# 迭代次数： 6779 最佳路径总距离： 3687
# 迭代次数： 6780 最佳路径总距离： 3687
# 迭代次数： 6781 最佳路径总距离： 3687
# 迭代次数： 6782 最佳路径总距离： 3687
# 迭代次数： 6783 最佳路径总距离： 3687
# 迭代次数： 6784 最佳路径总距离： 3687
# 迭代次数： 6785 最佳路径总距离： 3687
# 迭代次数： 6786 最佳路径总距离： 3687
# 迭代次数： 6787 最佳路径总距离： 3687
# 迭代次数： 6788 最佳路径总距离： 3687
# 迭代次数： 6789 最佳路径总距离： 3687
# 迭代次数： 6790 最佳路径总距离： 3687
# 迭代次数： 6791 最佳路径总距离： 3687
# 迭代次数： 6792 最佳路径总距离： 3687
# 迭代次数： 6793 最佳路径总距离： 3687
# 迭代次数： 6794 最佳路径总距离： 3687
# 迭代次数： 6795 最佳路径总距离： 3687
# 迭代次数： 6796 最佳路径总距离： 3687
# 迭代次数： 6797 最佳路径总距离： 3687
# 迭代次数： 6798 最佳路径总距离： 3687
# 迭代次数： 6799 最佳路径总距离： 3687
# 迭代次数： 6800 最佳路径总距离： 3687
# 迭代次数： 6801 最佳路径总距离： 3687
# 迭代次数： 6802 最佳路径总距离： 3687
# 迭代次数： 6803 最佳路径总距离： 3687
# 迭代次数： 6804 最佳路径总距离： 3687
# 迭代次数： 6805 最佳路径总距离： 3687
# 迭代次数： 6806 最佳路径总距离： 3687
# 迭代次数： 6807 最佳路径总距离： 3687
# 迭代次数： 6808 最佳路径总距离： 3687
# 迭代次数： 6809 最佳路径总距离： 3687
# 迭代次数： 6810 最佳路径总距离： 3687
# 迭代次数： 6811 最佳路径总距离： 3687
# 迭代次数： 6812 最佳路径总距离： 3687
# 迭代次数： 6813 最佳路径总距离： 3687
# 迭代次数： 6814 最佳路径总距离： 3687
# 迭代次数： 6815 最佳路径总距离： 3687
# 迭代次数： 6816 最佳路径总距离： 3687
# 迭代次数： 6817 最佳路径总距离： 3687
# 迭代次数： 6818 最佳路径总距离： 3687
# 迭代次数： 6819 最佳路径总距离： 3687
# 迭代次数： 6820 最佳路径总距离： 3687
# 迭代次数： 6821 最佳路径总距离： 3687
# 迭代次数： 6822 最佳路径总距离： 3687
# 迭代次数： 6823 最佳路径总距离： 3687
# 迭代次数： 6824 最佳路径总距离： 3687
# 迭代次数： 6825 最佳路径总距离： 3687
# 迭代次数： 6826 最佳路径总距离： 3687
# 迭代次数： 6827 最佳路径总距离： 3687
# 迭代次数： 6828 最佳路径总距离： 3687
# 迭代次数： 6829 最佳路径总距离： 3687
# 迭代次数： 6830 最佳路径总距离： 3687
# 迭代次数： 6831 最佳路径总距离： 3687
# 迭代次数： 6832 最佳路径总距离： 3687
# 迭代次数： 6833 最佳路径总距离： 3687
# 迭代次数： 6834 最佳路径总距离： 3687
# 迭代次数： 6835 最佳路径总距离： 3687
# 迭代次数： 6836 最佳路径总距离： 3687
# 迭代次数： 6837 最佳路径总距离： 3687
# 迭代次数： 6838 最佳路径总距离： 3687
# 迭代次数： 6839 最佳路径总距离： 3687
# 迭代次数： 6840 最佳路径总距离： 3687
# 迭代次数： 6841 最佳路径总距离： 3687
# 迭代次数： 6842 最佳路径总距离： 3687
# 迭代次数： 6843 最佳路径总距离： 3687
# 迭代次数： 6844 最佳路径总距离： 3687
# 迭代次数： 6845 最佳路径总距离： 3687
# 迭代次数： 6846 最佳路径总距离： 3687
# 迭代次数： 6847 最佳路径总距离： 3687
# 迭代次数： 6848 最佳路径总距离： 3687
# 迭代次数： 6849 最佳路径总距离： 3687
# 迭代次数： 6850 最佳路径总距离： 3687
# 迭代次数： 6851 最佳路径总距离： 3687
# 迭代次数： 6852 最佳路径总距离： 3687
# 迭代次数： 6853 最佳路径总距离： 3687
# 迭代次数： 6854 最佳路径总距离： 3687
# 迭代次数： 6855 最佳路径总距离： 3687
# 迭代次数： 6856 最佳路径总距离： 3687
# 迭代次数： 6857 最佳路径总距离： 3687
# 迭代次数： 6858 最佳路径总距离： 3687
# 迭代次数： 6859 最佳路径总距离： 3687
# 迭代次数： 6860 最佳路径总距离： 3687
# 迭代次数： 6861 最佳路径总距离： 3687
# 迭代次数： 6862 最佳路径总距离： 3687
# 迭代次数： 6863 最佳路径总距离： 3687
# 迭代次数： 6864 最佳路径总距离： 3687
# 迭代次数： 6865 最佳路径总距离： 3687
# 迭代次数： 6866 最佳路径总距离： 3687
# 迭代次数： 6867 最佳路径总距离： 3687
# 迭代次数： 6868 最佳路径总距离： 3687
# 迭代次数： 6869 最佳路径总距离： 3687
# 迭代次数： 6870 最佳路径总距离： 3687
# 迭代次数： 6871 最佳路径总距离： 3687
# 迭代次数： 6872 最佳路径总距离： 3687
# 迭代次数： 6873 最佳路径总距离： 3687
# 迭代次数： 6874 最佳路径总距离： 3687
# 迭代次数： 6875 最佳路径总距离： 3687
# 迭代次数： 6876 最佳路径总距离： 3687
# 迭代次数： 6877 最佳路径总距离： 3687
# 迭代次数： 6878 最佳路径总距离： 3687
# 迭代次数： 6879 最佳路径总距离： 3687
# 迭代次数： 6880 最佳路径总距离： 3687
# 迭代次数： 6881 最佳路径总距离： 3687
# 迭代次数： 6882 最佳路径总距离： 3687
# 迭代次数： 6883 最佳路径总距离： 3687
# 迭代次数： 6884 最佳路径总距离： 3687
# 迭代次数： 6885 最佳路径总距离： 3687
# 迭代次数： 6886 最佳路径总距离： 3687
# 迭代次数： 6887 最佳路径总距离： 3687
# 迭代次数： 6888 最佳路径总距离： 3687
# 迭代次数： 6889 最佳路径总距离： 3687
# 迭代次数： 6890 最佳路径总距离： 3687
# 迭代次数： 6891 最佳路径总距离： 3687
# 迭代次数： 6892 最佳路径总距离： 3687
# 迭代次数： 6893 最佳路径总距离： 3687
# 迭代次数： 6894 最佳路径总距离： 3687
# 迭代次数： 6895 最佳路径总距离： 3687
# 迭代次数： 6896 最佳路径总距离： 3687
# 迭代次数： 6897 最佳路径总距离： 3687
# 迭代次数： 6898 最佳路径总距离： 3687
# 迭代次数： 6899 最佳路径总距离： 3687
# 迭代次数： 6900 最佳路径总距离： 3687
# 迭代次数： 6901 最佳路径总距离： 3687
# 迭代次数： 6902 最佳路径总距离： 3687
# 迭代次数： 6903 最佳路径总距离： 3687
# 迭代次数： 6904 最佳路径总距离： 3687
# 迭代次数： 6905 最佳路径总距离： 3687
# 迭代次数： 6906 最佳路径总距离： 3687
# 迭代次数： 6907 最佳路径总距离： 3687
# 迭代次数： 6908 最佳路径总距离： 3687
# 迭代次数： 6909 最佳路径总距离： 3687
# 迭代次数： 6910 最佳路径总距离： 3687
# 迭代次数： 6911 最佳路径总距离： 3687
# 迭代次数： 6912 最佳路径总距离： 3687
# 迭代次数： 6913 最佳路径总距离： 3687
# 迭代次数： 6914 最佳路径总距离： 3687
# 迭代次数： 6915 最佳路径总距离： 3687
# 迭代次数： 6916 最佳路径总距离： 3687
# 迭代次数： 6917 最佳路径总距离： 3687
# 迭代次数： 6918 最佳路径总距离： 3687
# 迭代次数： 6919 最佳路径总距离： 3687
# 迭代次数： 6920 最佳路径总距离： 3687
# 迭代次数： 6921 最佳路径总距离： 3687
# 迭代次数： 6922 最佳路径总距离： 3687
# 迭代次数： 6923 最佳路径总距离： 3687
# 迭代次数： 6924 最佳路径总距离： 3687
# 迭代次数： 6925 最佳路径总距离： 3687
# 迭代次数： 6926 最佳路径总距离： 3687
# 迭代次数： 6927 最佳路径总距离： 3687
# 迭代次数： 6928 最佳路径总距离： 3687
# 迭代次数： 6929 最佳路径总距离： 3687
# 迭代次数： 6930 最佳路径总距离： 3687
# 迭代次数： 6931 最佳路径总距离： 3687
# 迭代次数： 6932 最佳路径总距离： 3687
# 迭代次数： 6933 最佳路径总距离： 3687
# 迭代次数： 6934 最佳路径总距离： 3687
# 迭代次数： 6935 最佳路径总距离： 3687
# 迭代次数： 6936 最佳路径总距离： 3687
# 迭代次数： 6937 最佳路径总距离： 3687
# 迭代次数： 6938 最佳路径总距离： 3687
# 迭代次数： 6939 最佳路径总距离： 3687
# 迭代次数： 6940 最佳路径总距离： 3687
# 迭代次数： 6941 最佳路径总距离： 3687
# 迭代次数： 6942 最佳路径总距离： 3687
# 迭代次数： 6943 最佳路径总距离： 3687
# 迭代次数： 6944 最佳路径总距离： 3687
# 迭代次数： 6945 最佳路径总距离： 3687
# 迭代次数： 6946 最佳路径总距离： 3687
# 迭代次数： 6947 最佳路径总距离： 3687
# 迭代次数： 6948 最佳路径总距离： 3687
# 迭代次数： 6949 最佳路径总距离： 3687
# 迭代次数： 6950 最佳路径总距离： 3687
# 迭代次数： 6951 最佳路径总距离： 3687
# 迭代次数： 6952 最佳路径总距离： 3687
# 迭代次数： 6953 最佳路径总距离： 3687
# 迭代次数： 6954 最佳路径总距离： 3687
# 迭代次数： 6955 最佳路径总距离： 3687
# 迭代次数： 6956 最佳路径总距离： 3687
# 迭代次数： 6957 最佳路径总距离： 3687
# 迭代次数： 6958 最佳路径总距离： 3687
# 迭代次数： 6959 最佳路径总距离： 3687
# 迭代次数： 6960 最佳路径总距离： 3687
# 迭代次数： 6961 最佳路径总距离： 3687
# 迭代次数： 6962 最佳路径总距离： 3687
# 迭代次数： 6963 最佳路径总距离： 3687
# 迭代次数： 6964 最佳路径总距离： 3687
# 迭代次数： 6965 最佳路径总距离： 3687
# 迭代次数： 6966 最佳路径总距离： 3687
# 迭代次数： 6967 最佳路径总距离： 3687
# 迭代次数： 6968 最佳路径总距离： 3687
# 迭代次数： 6969 最佳路径总距离： 3687
# 迭代次数： 6970 最佳路径总距离： 3687
# 迭代次数： 6971 最佳路径总距离： 3687
# 迭代次数： 6972 最佳路径总距离： 3687
# 迭代次数： 6973 最佳路径总距离： 3687
# 迭代次数： 6974 最佳路径总距离： 3687
# 迭代次数： 6975 最佳路径总距离： 3687
# 迭代次数： 6976 最佳路径总距离： 3687
# 迭代次数： 6977 最佳路径总距离： 3687
# 迭代次数： 6978 最佳路径总距离： 3687
# 迭代次数： 6979 最佳路径总距离： 3687
# 迭代次数： 6980 最佳路径总距离： 3687
# 迭代次数： 6981 最佳路径总距离： 3687
# 迭代次数： 6982 最佳路径总距离： 3687
# 迭代次数： 6983 最佳路径总距离： 3687
# 迭代次数： 6984 最佳路径总距离： 3687
# 迭代次数： 6985 最佳路径总距离： 3687
# 迭代次数： 6986 最佳路径总距离： 3687
# 迭代次数： 6987 最佳路径总距离： 3687
# 迭代次数： 6988 最佳路径总距离： 3687
# 迭代次数： 6989 最佳路径总距离： 3687
# 迭代次数： 6990 最佳路径总距离： 3687
# 迭代次数： 6991 最佳路径总距离： 3687
# 迭代次数： 6992 最佳路径总距离： 3687
# 迭代次数： 6993 最佳路径总距离： 3687
# 迭代次数： 6994 最佳路径总距离： 3687
# 迭代次数： 6995 最佳路径总距离： 3687
# 迭代次数： 6996 最佳路径总距离： 3687
# 迭代次数： 6997 最佳路径总距离： 3687
# 迭代次数： 6998 最佳路径总距离： 3687
# 迭代次数： 6999 最佳路径总距离： 3687
# 迭代次数： 7000 最佳路径总距离： 3687
# 迭代次数： 7001 最佳路径总距离： 3687
# 迭代次数： 7002 最佳路径总距离： 3687
# 迭代次数： 7003 最佳路径总距离： 3687
# 迭代次数： 7004 最佳路径总距离： 3687
# 迭代次数： 7005 最佳路径总距离： 3687
# 迭代次数： 7006 最佳路径总距离： 3687
# 迭代次数： 7007 最佳路径总距离： 3687
# 迭代次数： 7008 最佳路径总距离： 3687
# 迭代次数： 7009 最佳路径总距离： 3687
# 迭代次数： 7010 最佳路径总距离： 3687
# 迭代次数： 7011 最佳路径总距离： 3687
# 迭代次数： 7012 最佳路径总距离： 3687
# 迭代次数： 7013 最佳路径总距离： 3687
# 迭代次数： 7014 最佳路径总距离： 3687
# 迭代次数： 7015 最佳路径总距离： 3687
# 迭代次数： 7016 最佳路径总距离： 3687
# 迭代次数： 7017 最佳路径总距离： 3687
# 迭代次数： 7018 最佳路径总距离： 3687
# 迭代次数： 7019 最佳路径总距离： 3687
# 迭代次数： 7020 最佳路径总距离： 3687
# 迭代次数： 7021 最佳路径总距离： 3687
# 迭代次数： 7022 最佳路径总距离： 3687
# 迭代次数： 7023 最佳路径总距离： 3687
# 迭代次数： 7024 最佳路径总距离： 3687
# 迭代次数： 7025 最佳路径总距离： 3687
# 迭代次数： 7026 最佳路径总距离： 3687
# 迭代次数： 7027 最佳路径总距离： 3687
# 迭代次数： 7028 最佳路径总距离： 3687
# 迭代次数： 7029 最佳路径总距离： 3687
# 迭代次数： 7030 最佳路径总距离： 3687
# 迭代次数： 7031 最佳路径总距离： 3687
# 迭代次数： 7032 最佳路径总距离： 3687
# 迭代次数： 7033 最佳路径总距离： 3687
# 迭代次数： 7034 最佳路径总距离： 3687
# 迭代次数： 7035 最佳路径总距离： 3687
# 迭代次数： 7036 最佳路径总距离： 3687
# 迭代次数： 7037 最佳路径总距离： 3687
# 迭代次数： 7038 最佳路径总距离： 3687
# 迭代次数： 7039 最佳路径总距离： 3687
# 迭代次数： 7040 最佳路径总距离： 3687
# 迭代次数： 7041 最佳路径总距离： 3687
# 迭代次数： 7042 最佳路径总距离： 3687
# 迭代次数： 7043 最佳路径总距离： 3687
# 迭代次数： 7044 最佳路径总距离： 3687
# 迭代次数： 7045 最佳路径总距离： 3687
# 迭代次数： 7046 最佳路径总距离： 3687
# 迭代次数： 7047 最佳路径总距离： 3687
# 迭代次数： 7048 最佳路径总距离： 3687
# 迭代次数： 7049 最佳路径总距离： 3687
# 迭代次数： 7050 最佳路径总距离： 3687
# 迭代次数： 7051 最佳路径总距离： 3687
# 迭代次数： 7052 最佳路径总距离： 3687
# 迭代次数： 7053 最佳路径总距离： 3687
# 迭代次数： 7054 最佳路径总距离： 3687
# 迭代次数： 7055 最佳路径总距离： 3687
# 迭代次数： 7056 最佳路径总距离： 3687
# 迭代次数： 7057 最佳路径总距离： 3687
# 迭代次数： 7058 最佳路径总距离： 3687
# 迭代次数： 7059 最佳路径总距离： 3687
# 迭代次数： 7060 最佳路径总距离： 3687
# 迭代次数： 7061 最佳路径总距离： 3687
# 迭代次数： 7062 最佳路径总距离： 3687
# 迭代次数： 7063 最佳路径总距离： 3687
# 迭代次数： 7064 最佳路径总距离： 3687
# 迭代次数： 7065 最佳路径总距离： 3687
# 迭代次数： 7066 最佳路径总距离： 3687
# 迭代次数： 7067 最佳路径总距离： 3687
# 迭代次数： 7068 最佳路径总距离： 3687
# 迭代次数： 7069 最佳路径总距离： 3687
# 迭代次数： 7070 最佳路径总距离： 3687
# 迭代次数： 7071 最佳路径总距离： 3687
# 迭代次数： 7072 最佳路径总距离： 3687
# 迭代次数： 7073 最佳路径总距离： 3687
# 迭代次数： 7074 最佳路径总距离： 3687
# 迭代次数： 7075 最佳路径总距离： 3687
# 迭代次数： 7076 最佳路径总距离： 3687
# 迭代次数： 7077 最佳路径总距离： 3687
# 迭代次数： 7078 最佳路径总距离： 3687
# 迭代次数： 7079 最佳路径总距离： 3687
# 迭代次数： 7080 最佳路径总距离： 3687
# 迭代次数： 7081 最佳路径总距离： 3687
# 迭代次数： 7082 最佳路径总距离： 3687
# 迭代次数： 7083 最佳路径总距离： 3687
# 迭代次数： 7084 最佳路径总距离： 3687
# 迭代次数： 7085 最佳路径总距离： 3687
# 迭代次数： 7086 最佳路径总距离： 3687
# 迭代次数： 7087 最佳路径总距离： 3687
# 迭代次数： 7088 最佳路径总距离： 3687
# 迭代次数： 7089 最佳路径总距离： 3687
# 迭代次数： 7090 最佳路径总距离： 3687
# 迭代次数： 7091 最佳路径总距离： 3687
# 迭代次数： 7092 最佳路径总距离： 3687
# 迭代次数： 7093 最佳路径总距离： 3687
# 迭代次数： 7094 最佳路径总距离： 3687
# 迭代次数： 7095 最佳路径总距离： 3687
# 迭代次数： 7096 最佳路径总距离： 3687
# 迭代次数： 7097 最佳路径总距离： 3687
# 迭代次数： 7098 最佳路径总距离： 3687
# 迭代次数： 7099 最佳路径总距离： 3687
# 迭代次数： 7100 最佳路径总距离： 3687
# 迭代次数： 7101 最佳路径总距离： 3687
# 迭代次数： 7102 最佳路径总距离： 3687
# 迭代次数： 7103 最佳路径总距离： 3687
# 迭代次数： 7104 最佳路径总距离： 3687
# 迭代次数： 7105 最佳路径总距离： 3687
# 迭代次数： 7106 最佳路径总距离： 3687
# 迭代次数： 7107 最佳路径总距离： 3687
# 迭代次数： 7108 最佳路径总距离： 3687
# 迭代次数： 7109 最佳路径总距离： 3687
# 迭代次数： 7110 最佳路径总距离： 3687
# 迭代次数： 7111 最佳路径总距离： 3687
# 迭代次数： 7112 最佳路径总距离： 3687
# 迭代次数： 7113 最佳路径总距离： 3687
# 迭代次数： 7114 最佳路径总距离： 3687
# 迭代次数： 7115 最佳路径总距离： 3687
# 迭代次数： 7116 最佳路径总距离： 3687
# 迭代次数： 7117 最佳路径总距离： 3687
# 迭代次数： 7118 最佳路径总距离： 3687
# 迭代次数： 7119 最佳路径总距离： 3687
# 迭代次数： 7120 最佳路径总距离： 3687
# 迭代次数： 7121 最佳路径总距离： 3687
# 迭代次数： 7122 最佳路径总距离： 3687
# 迭代次数： 7123 最佳路径总距离： 3687
# 迭代次数： 7124 最佳路径总距离： 3687
# 迭代次数： 7125 最佳路径总距离： 3687
# 迭代次数： 7126 最佳路径总距离： 3687
# 迭代次数： 7127 最佳路径总距离： 3687
# 迭代次数： 7128 最佳路径总距离： 3687
# 迭代次数： 7129 最佳路径总距离： 3687
# 迭代次数： 7130 最佳路径总距离： 3687
# 迭代次数： 7131 最佳路径总距离： 3687
# 迭代次数： 7132 最佳路径总距离： 3687
# 迭代次数： 7133 最佳路径总距离： 3687
# 迭代次数： 7134 最佳路径总距离： 3687
# 迭代次数： 7135 最佳路径总距离： 3687
# 迭代次数： 7136 最佳路径总距离： 3687
# 迭代次数： 7137 最佳路径总距离： 3687
# 迭代次数： 7138 最佳路径总距离： 3687
# 迭代次数： 7139 最佳路径总距离： 3687
# 迭代次数： 7140 最佳路径总距离： 3687
# 迭代次数： 7141 最佳路径总距离： 3687
# 迭代次数： 7142 最佳路径总距离： 3687
# 迭代次数： 7143 最佳路径总距离： 3687
# 迭代次数： 7144 最佳路径总距离： 3687
# 迭代次数： 7145 最佳路径总距离： 3687
# 迭代次数： 7146 最佳路径总距离： 3687
# 迭代次数： 7147 最佳路径总距离： 3687
# 迭代次数： 7148 最佳路径总距离： 3687
# 迭代次数： 7149 最佳路径总距离： 3687
# 迭代次数： 7150 最佳路径总距离： 3687
# 迭代次数： 7151 最佳路径总距离： 3687
# 迭代次数： 7152 最佳路径总距离： 3687
# 迭代次数： 7153 最佳路径总距离： 3687
# 迭代次数： 7154 最佳路径总距离： 3687
# 迭代次数： 7155 最佳路径总距离： 3687
# 迭代次数： 7156 最佳路径总距离： 3687
# 迭代次数： 7157 最佳路径总距离： 3687
# 迭代次数： 7158 最佳路径总距离： 3687
# 迭代次数： 7159 最佳路径总距离： 3687
# 迭代次数： 7160 最佳路径总距离： 3687
# 迭代次数： 7161 最佳路径总距离： 3687
# 迭代次数： 7162 最佳路径总距离： 3687
# 迭代次数： 7163 最佳路径总距离： 3687
# 迭代次数： 7164 最佳路径总距离： 3687
# 迭代次数： 7165 最佳路径总距离： 3687
# 迭代次数： 7166 最佳路径总距离： 3687
# 迭代次数： 7167 最佳路径总距离： 3687
# 迭代次数： 7168 最佳路径总距离： 3687
# 迭代次数： 7169 最佳路径总距离： 3687
# 迭代次数： 7170 最佳路径总距离： 3687
# 迭代次数： 7171 最佳路径总距离： 3687
# 迭代次数： 7172 最佳路径总距离： 3687
# 迭代次数： 7173 最佳路径总距离： 3687
# 迭代次数： 7174 最佳路径总距离： 3687
# 迭代次数： 7175 最佳路径总距离： 3687
# 迭代次数： 7176 最佳路径总距离： 3687
# 迭代次数： 7177 最佳路径总距离： 3687
# 迭代次数： 7178 最佳路径总距离： 3687
# 迭代次数： 7179 最佳路径总距离： 3687
# 迭代次数： 7180 最佳路径总距离： 3687
# 迭代次数： 7181 最佳路径总距离： 3687
# 迭代次数： 7182 最佳路径总距离： 3687
# 迭代次数： 7183 最佳路径总距离： 3687
# 迭代次数： 7184 最佳路径总距离： 3687
# 迭代次数： 7185 最佳路径总距离： 3687
# 迭代次数： 7186 最佳路径总距离： 3687
# 迭代次数： 7187 最佳路径总距离： 3687
# 迭代次数： 7188 最佳路径总距离： 3687
# 迭代次数： 7189 最佳路径总距离： 3687
# 迭代次数： 7190 最佳路径总距离： 3687
# 迭代次数： 7191 最佳路径总距离： 3687
# 迭代次数： 7192 最佳路径总距离： 3687
# 迭代次数： 7193 最佳路径总距离： 3687
# 迭代次数： 7194 最佳路径总距离： 3687
# 迭代次数： 7195 最佳路径总距离： 3687
# 迭代次数： 7196 最佳路径总距离： 3687
# 迭代次数： 7197 最佳路径总距离： 3687
# 迭代次数： 7198 最佳路径总距离： 3687
# 迭代次数： 7199 最佳路径总距离： 3687
# 迭代次数： 7200 最佳路径总距离： 3687
# 迭代次数： 7201 最佳路径总距离： 3687
# 迭代次数： 7202 最佳路径总距离： 3687
# 迭代次数： 7203 最佳路径总距离： 3687
# 迭代次数： 7204 最佳路径总距离： 3687
# 迭代次数： 7205 最佳路径总距离： 3687
# 迭代次数： 7206 最佳路径总距离： 3687
# 迭代次数： 7207 最佳路径总距离： 3687
# 迭代次数： 7208 最佳路径总距离： 3687
# 迭代次数： 7209 最佳路径总距离： 3687
# 迭代次数： 7210 最佳路径总距离： 3687
# 迭代次数： 7211 最佳路径总距离： 3687
# 迭代次数： 7212 最佳路径总距离： 3687
# 迭代次数： 7213 最佳路径总距离： 3687
# 迭代次数： 7214 最佳路径总距离： 3687
# 迭代次数： 7215 最佳路径总距离： 3687
# 迭代次数： 7216 最佳路径总距离： 3687
# 迭代次数： 7217 最佳路径总距离： 3687
# 迭代次数： 7218 最佳路径总距离： 3687
# 迭代次数： 7219 最佳路径总距离： 3687
# 迭代次数： 7220 最佳路径总距离： 3687
# 迭代次数： 7221 最佳路径总距离： 3687
# 迭代次数： 7222 最佳路径总距离： 3687
# 迭代次数： 7223 最佳路径总距离： 3687
# 迭代次数： 7224 最佳路径总距离： 3687
# 迭代次数： 7225 最佳路径总距离： 3687
# 迭代次数： 7226 最佳路径总距离： 3687
# 迭代次数： 7227 最佳路径总距离： 3687
# 迭代次数： 7228 最佳路径总距离： 3687
# 迭代次数： 7229 最佳路径总距离： 3687
# 迭代次数： 7230 最佳路径总距离： 3687
# 迭代次数： 7231 最佳路径总距离： 3687
# 迭代次数： 7232 最佳路径总距离： 3687
# 迭代次数： 7233 最佳路径总距离： 3687
# 迭代次数： 7234 最佳路径总距离： 3687
# 迭代次数： 7235 最佳路径总距离： 3687
# 迭代次数： 7236 最佳路径总距离： 3687
# 迭代次数： 7237 最佳路径总距离： 3687
# 迭代次数： 7238 最佳路径总距离： 3687
# 迭代次数： 7239 最佳路径总距离： 3687
# 迭代次数： 7240 最佳路径总距离： 3687
# 迭代次数： 7241 最佳路径总距离： 3687
# 迭代次数： 7242 最佳路径总距离： 3687
# 迭代次数： 7243 最佳路径总距离： 3687
# 迭代次数： 7244 最佳路径总距离： 3687
# 迭代次数： 7245 最佳路径总距离： 3687
# 迭代次数： 7246 最佳路径总距离： 3687
# 迭代次数： 7247 最佳路径总距离： 3687
# 迭代次数： 7248 最佳路径总距离： 3687
# 迭代次数： 7249 最佳路径总距离： 3687
# 迭代次数： 7250 最佳路径总距离： 3687
# 迭代次数： 7251 最佳路径总距离： 3687
# 迭代次数： 7252 最佳路径总距离： 3687
# 迭代次数： 7253 最佳路径总距离： 3687
# 迭代次数： 7254 最佳路径总距离： 3687
# 迭代次数： 7255 最佳路径总距离： 3687
# 迭代次数： 7256 最佳路径总距离： 3687
# 迭代次数： 7257 最佳路径总距离： 3687
# 迭代次数： 7258 最佳路径总距离： 3687
# 迭代次数： 7259 最佳路径总距离： 3687
# 迭代次数： 7260 最佳路径总距离： 3687
# 迭代次数： 7261 最佳路径总距离： 3687
# 迭代次数： 7262 最佳路径总距离： 3687
# 迭代次数： 7263 最佳路径总距离： 3687
# 迭代次数： 7264 最佳路径总距离： 3687
# 迭代次数： 7265 最佳路径总距离： 3687
# 迭代次数： 7266 最佳路径总距离： 3687
# 迭代次数： 7267 最佳路径总距离： 3687
# 迭代次数： 7268 最佳路径总距离： 3687
# 迭代次数： 7269 最佳路径总距离： 3687
# 迭代次数： 7270 最佳路径总距离： 3687
# 迭代次数： 7271 最佳路径总距离： 3687
# 迭代次数： 7272 最佳路径总距离： 3687
# 迭代次数： 7273 最佳路径总距离： 3687
# 迭代次数： 7274 最佳路径总距离： 3687
# 迭代次数： 7275 最佳路径总距离： 3687
# 迭代次数： 7276 最佳路径总距离： 3687
# 迭代次数： 7277 最佳路径总距离： 3687
# 迭代次数： 7278 最佳路径总距离： 3687
# 迭代次数： 7279 最佳路径总距离： 3687
# 迭代次数： 7280 最佳路径总距离： 3687
# 迭代次数： 7281 最佳路径总距离： 3687
# 迭代次数： 7282 最佳路径总距离： 3687
# 迭代次数： 7283 最佳路径总距离： 3687
# 迭代次数： 7284 最佳路径总距离： 3687
# 迭代次数： 7285 最佳路径总距离： 3687
# 迭代次数： 7286 最佳路径总距离： 3687
# 迭代次数： 7287 最佳路径总距离： 3687
# 迭代次数： 7288 最佳路径总距离： 3687
# 迭代次数： 7289 最佳路径总距离： 3687
# 迭代次数： 7290 最佳路径总距离： 3687
# 迭代次数： 7291 最佳路径总距离： 3687
# 迭代次数： 7292 最佳路径总距离： 3687
# 迭代次数： 7293 最佳路径总距离： 3687
# 迭代次数： 7294 最佳路径总距离： 3687
# 迭代次数： 7295 最佳路径总距离： 3687
# 迭代次数： 7296 最佳路径总距离： 3687
# 迭代次数： 7297 最佳路径总距离： 3687
# 迭代次数： 7298 最佳路径总距离： 3687
# 迭代次数： 7299 最佳路径总距离： 3687
# 迭代次数： 7300 最佳路径总距离： 3687
# 迭代次数： 7301 最佳路径总距离： 3687
# 迭代次数： 7302 最佳路径总距离： 3687
# 迭代次数： 7303 最佳路径总距离： 3687
# 迭代次数： 7304 最佳路径总距离： 3687
# 迭代次数： 7305 最佳路径总距离： 3687
# 迭代次数： 7306 最佳路径总距离： 3687
# 迭代次数： 7307 最佳路径总距离： 3687
# 迭代次数： 7308 最佳路径总距离： 3687
# 迭代次数： 7309 最佳路径总距离： 3687
# 迭代次数： 7310 最佳路径总距离： 3687
# 迭代次数： 7311 最佳路径总距离： 3687
# 迭代次数： 7312 最佳路径总距离： 3687
# 迭代次数： 7313 最佳路径总距离： 3687
# 迭代次数： 7314 最佳路径总距离： 3687
# 迭代次数： 7315 最佳路径总距离： 3687
# 迭代次数： 7316 最佳路径总距离： 3687
# 迭代次数： 7317 最佳路径总距离： 3687
# 迭代次数： 7318 最佳路径总距离： 3687
# 迭代次数： 7319 最佳路径总距离： 3687
# 迭代次数： 7320 最佳路径总距离： 3687
# 迭代次数： 7321 最佳路径总距离： 3687
# 迭代次数： 7322 最佳路径总距离： 3687
# 迭代次数： 7323 最佳路径总距离： 3687
# 迭代次数： 7324 最佳路径总距离： 3687
# 迭代次数： 7325 最佳路径总距离： 3687
# 迭代次数： 7326 最佳路径总距离： 3687
# 迭代次数： 7327 最佳路径总距离： 3687
# 迭代次数： 7328 最佳路径总距离： 3687
# 迭代次数： 7329 最佳路径总距离： 3687
# 迭代次数： 7330 最佳路径总距离： 3687
# 迭代次数： 7331 最佳路径总距离： 3687
# 迭代次数： 7332 最佳路径总距离： 3687
# 迭代次数： 7333 最佳路径总距离： 3687
# 迭代次数： 7334 最佳路径总距离： 3687
# 迭代次数： 7335 最佳路径总距离： 3687
# 迭代次数： 7336 最佳路径总距离： 3687
# 迭代次数： 7337 最佳路径总距离： 3687
# 迭代次数： 7338 最佳路径总距离： 3687
# 迭代次数： 7339 最佳路径总距离： 3687
# 迭代次数： 7340 最佳路径总距离： 3687
# 迭代次数： 7341 最佳路径总距离： 3687
# 迭代次数： 7342 最佳路径总距离： 3687
# 迭代次数： 7343 最佳路径总距离： 3687
# 迭代次数： 7344 最佳路径总距离： 3687
# 迭代次数： 7345 最佳路径总距离： 3687
# 迭代次数： 7346 最佳路径总距离： 3687
# 迭代次数： 7347 最佳路径总距离： 3687
# 迭代次数： 7348 最佳路径总距离： 3687
# 迭代次数： 7349 最佳路径总距离： 3687
# 迭代次数： 7350 最佳路径总距离： 3687
# 迭代次数： 7351 最佳路径总距离： 3687
# 迭代次数： 7352 最佳路径总距离： 3687
# 迭代次数： 7353 最佳路径总距离： 3687
# 迭代次数： 7354 最佳路径总距离： 3687
# 迭代次数： 7355 最佳路径总距离： 3687
# 迭代次数： 7356 最佳路径总距离： 3687
# 迭代次数： 7357 最佳路径总距离： 3687
# 迭代次数： 7358 最佳路径总距离： 3687
# 迭代次数： 7359 最佳路径总距离： 3687
# 迭代次数： 7360 最佳路径总距离： 3687
# 迭代次数： 7361 最佳路径总距离： 3687
# 迭代次数： 7362 最佳路径总距离： 3687
# 迭代次数： 7363 最佳路径总距离： 3687
# 迭代次数： 7364 最佳路径总距离： 3687
# 迭代次数： 7365 最佳路径总距离： 3687
# 迭代次数： 7366 最佳路径总距离： 3687
# 迭代次数： 7367 最佳路径总距离： 3687
# 迭代次数： 7368 最佳路径总距离： 3687
# 迭代次数： 7369 最佳路径总距离： 3687
# 迭代次数： 7370 最佳路径总距离： 3687
# 迭代次数： 7371 最佳路径总距离： 3687
# 迭代次数： 7372 最佳路径总距离： 3687
# 迭代次数： 7373 最佳路径总距离： 3687
# 迭代次数： 7374 最佳路径总距离： 3687
# 迭代次数： 7375 最佳路径总距离： 3687
# 迭代次数： 7376 最佳路径总距离： 3687
# 迭代次数： 7377 最佳路径总距离： 3687
# 迭代次数： 7378 最佳路径总距离： 3687
# 迭代次数： 7379 最佳路径总距离： 3687
# 迭代次数： 7380 最佳路径总距离： 3687
# 迭代次数： 7381 最佳路径总距离： 3687
# 迭代次数： 7382 最佳路径总距离： 3687
# 迭代次数： 7383 最佳路径总距离： 3687
# 迭代次数： 7384 最佳路径总距离： 3687
# 迭代次数： 7385 最佳路径总距离： 3687
# 迭代次数： 7386 最佳路径总距离： 3687
# 迭代次数： 7387 最佳路径总距离： 3687
# 迭代次数： 7388 最佳路径总距离： 3687
# 迭代次数： 7389 最佳路径总距离： 3687
# 迭代次数： 7390 最佳路径总距离： 3687
# 迭代次数： 7391 最佳路径总距离： 3687
# 迭代次数： 7392 最佳路径总距离： 3687
# 迭代次数： 7393 最佳路径总距离： 3687
# 迭代次数： 7394 最佳路径总距离： 3687
# 迭代次数： 7395 最佳路径总距离： 3687
# 迭代次数： 7396 最佳路径总距离： 3687
# 迭代次数： 7397 最佳路径总距离： 3687
# 迭代次数： 7398 最佳路径总距离： 3687
# 迭代次数： 7399 最佳路径总距离： 3687
# 迭代次数： 7400 最佳路径总距离： 3687
# 迭代次数： 7401 最佳路径总距离： 3687
#
# 程序已退出...
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# e:\anaconda\envs\d2l\lib\site-packages\IPython\core\interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
